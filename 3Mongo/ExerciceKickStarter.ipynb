# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient('mongo')
database = client['exercices']
collection = database['kickstarter']

# %%
collection.drop()

# %%
def parse_date(x) :
    try :
        return datetime.strptime(x, "%Y-%m-%d %H:%M:%S")
    except :
        return datetime.now()

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv", parse_dates=['launched'])
df_ks['launched'] = df_ks['launched'].apply(parse_date)

# %%
df_ks.head()
# Out:
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#              launched pledged       state backers country usd pledged  \
# 0 2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1 2012-07-23 20:46:48    1851      failed      28      US        1851
# 2 2016-07-01 21:55:54    7534  successful     254      US        3796
# 3 2017-08-28 15:47:02   16298  successful     367      US        2670
# 4 2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %%
df_ks.dtypes
# Out:
# ID                           int64
# name                        object
# category                    object
# main_category               object
# currency                    object
# deadline                    object
# goal                        object
# launched            datetime64[ns]
# pledged                     object
# state                       object
# backers                     object
# country                     object
# usd pledged                 object
# usd_pledged_real           float64
# dtype: object

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks.isnull().sum()
# Out:
# ID                     0
# name                   2
# category               0
# main_category          0
# currency               0
# deadline               0
# goal                   0
# launched               0
# pledged                0
# state                  0
# backers                0
# country                0
# usd pledged         1482
# usd_pledged_real       0
# dtype: int64

# %% [markdown]
# ### Importer les données

# %%
dict_donnees = df_ks.to_dict('records')

# %%
collection.insert_many(dict_donnees)

# %% [markdown]
# ## Question 1
#
# Récupérer les 5 projets ayant reçu le plus de promesse de dons.

# %%
cur = collection.find({}).sort([("pledged", -1)]).limit(5)
list(cur)
# Out:
# [{'_id': ObjectId('5fc4e26892f46015ba481912'),
#   'ID': 218218259,
#   'name': 'True North ï¿½ Repurposed Sailcloth Products',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-06-14',
#   'goal': '7500.0',
#   'launched': '2016-05-10 15:53:56',
#   'pledged': '9996.0',
#   'state': 'successful',
#   'backers': '50',
#   'country': 'US',
#   'usd pledged': '9996.0',
#   'usd_pledged_real': 9996.0},
#  {'_id': ObjectId('5fc4e26892f46015ba47c7f0'),
#   'ID': 1712352341,
#   'name': 'Scott Davis - Solo Record',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-11-22',
#   'goal': '8000.0',
#   'launched': '2014-10-23 20:06:37',
#   'pledged': '9995.0',
#   'state': 'undefined',
#   'backers': '0',
#   'country': 'N,0"',
#   'usd pledged': nan,
#   'usd_pledged_real': 9995.0},
#  {'_id': ObjectId('5fc4e26792f46015ba479fa0'),
#   'ID': 1742823215,
#   'name': 'Polco: A Digital Platform for Better Civic Communication',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-08-11',
#   'goal': '35000.0',
#   'launched': '2017-06-27 21:46:04',
#   'pledged': '9994.0',
#   'state': 'failed',
#   'backers': '93',
#   'country': 'US',
#   'usd pledged': '876.0',
#   'usd_pledged_real': 9994.0},
#  {'_id': ObjectId('5fc4e26792f46015ba478575'),
#   'ID': 1247285954,
#   'name': '2016 Gaming Calendar',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-07-25',
#   'goal': '3000.0',
#   'launched': '2015-06-26 14:57:14',
#   'pledged': '9994.0',
#   'state': 'successful',
#   'backers': '258',
#   'country': 'US',
#   'usd pledged': '9994.0',
#   'usd_pledged_real': 9994.0},
#  {'_id': ObjectId('5fc4e26892f46015ba47b90a'),
#   'ID': 796104705,
#   'name': 'The Girl in The Mountain - Film',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2015-10-01',
#   'goal': '6500.0',
#   'launched': '2015-08-31 02:11:11',
#   'pledged': '999.0',
#   'state': 'failed',
#   'backers': '12',
#   'country': 'GB',
#   'usd pledged': '1537.65168912',
#   'usd_pledged_real': 1515.1974761875872}]

# %% [markdown]
# ## Question 2
#
# Compter le nombre de projets ayant atteint leur but.

# %%
collection.find({"state" : "successful"}).count(True)
# Out:
# <ipython-input-23-31eadd052d5d>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   collection.find({"state" : "successful"}).count(True)
# 53040

# %% [markdown]
# ## Question 3
#
# Compter le nombre de projets pour chaque catégorie.

# %%
df_ks['country'].unique()
# Out:
# array(['US', 'CA', 'HK', 'BE', 'GB', 'NO', 'NL', 'N,0"', 'AU', 'CH', 'SE',
#        'AT', 'NZ', 'MX', 'FR', 'DK', 'IT', 'ES', 'DE', 'IE', 'SG', 'LU',
#        'JP', '32'], dtype=object)

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$category", "count" : {"$sum" : 1}}}])
list(cur)
# Out:
# [{'_id': 'Public Art', 'count': 1248},
#  {'_id': 'Pet Fashion', 'count': 51},
#  {'_id': 'Workshops', 'count': 59},
#  {'_id': 'Digital Art', 'count': 524},
#  {'_id': 'Places', 'count': 283},
#  {'_id': 'Couture', 'count': 108},
#  {'_id': 'Gadgets', 'count': 1210},
#  {'_id': 'Web', 'count': 2017},
#  {'_id': 'Blues', 'count': 113},
#  {'_id': 'Candles', 'count': 168},
#  {'_id': 'Farms', 'count': 482},
#  {'_id': 'Plays', 'count': 539},
#  {'_id': 'Horror', 'count': 525},
#  {'_id': 'Installations', 'count': 178},
#  {'_id': 'Space Exploration', 'count': 137},
#  {'_id': 'Design', 'count': 1641},
#  {'_id': 'Bacon', 'count': 78},
#  {'_id': 'Printing', 'count': 83},
#  {'_id': 'Cookbooks', 'count': 217},
#  {'_id': 'Crafts', 'count': 1834},
#  {'_id': 'Illustration', 'count': 1263},
#  {'_id': 'Hip-Hop', 'count': 1555},
#  {'_id': 'World Music', 'count': 850},
#  {'_id': 'Art Books', 'count': 1065},
#  {'_id': 'Jazz', 'count': 733},
#  {'_id': 'Photo', 'count': 58},
#  {'_id': 'Software', 'count': 1194},
#  {'_id': 'Faith', 'count': 439},
#  {'_id': 'Experimental', 'count': 357},
#  {'_id': 'Playing Cards', 'count': 963},
#  {'_id': 'Glass', 'count': 51},
#  {'_id': 'Music Videos', 'count': 299},
#  {'_id': 'Taxidermy', 'count': 7},
#  {'_id': 'Pop', 'count': 1302},
#  {'_id': 'Ready-to-wear', 'count': 332},
#  {'_id': 'Drama', 'count': 871},
#  {'_id': 'Anthologies', 'count': 300},
#  {'_id': 'Apparel', 'count': 2827},
#  {'_id': 'DIY Electronics', 'count': 358},
#  {'_id': 'People', 'count': 440},
#  {'_id': 'Film & Video', 'count': 4003},
#  {'_id': 'Apps', 'count': 2535},
#  {'_id': 'Musical', 'count': 367},
#  {'_id': 'Science Fiction', 'count': 274},
#  {'_id': 'Painting', 'count': 1288},
#  {'_id': 'Music', 'count': 6229},
#  {'_id': 'Electronic Music', 'count': 858},
#  {'_id': 'Spaces', 'count': 331},
#  {'_id': 'Nonfiction', 'count': 3390},
#  {'_id': 'Photography', 'count': 2239},
#  {'_id': 'Young Adult', 'count': 328},
#  {'_id': 'Knitting', 'count': 78},
#  {'_id': 'Grace is Leaving', 'count': 1},
#  {'_id': "Children's Books", 'count': 2686},
#  {'_id': 'Fashion', 'count': 3379},
#  {'_id': 'Chiptune', 'count': 10},
#  {'_id': 'Hardware', 'count': 1431},
#  {'_id': 'Pottery', 'count': 40},
#  {'_id': 'Restaurants', 'count': 1089},
#  {'_id': 'Live Games', 'count': 394},
#  {'_id': 'Residencies', 'count': 32},
#  {'_id': 'Theater', 'count': 2786},
#  {'_id': 'DIY', 'count': 480},
#  {'_id': 'Journalism', 'count': 672},
#  {'_id': 'Typography', 'count': 44},
#  {'_id': 'Classical Music', 'count': 1064},
#  {'_id': 'Zines', 'count': 144},
#  {'_id': 'Childrenswear', 'count': 192},
#  {'_id': 'Accessories', 'count': 1204},
#  {'_id': 'Publishing', 'count': 2332},
#  {'_id': 'Family', 'count': 130},
#  {'_id': 'Art', 'count': 3358},
#  {'_id': 'Product Design', 'count': 8886},
#  {'_id': 'Sculpture', 'count': 737},
#  {'_id': 'Flight', 'count': 158},
#  {'_id': 'Stationery', 'count': 90},
#  {'_id': 'Fine Art', 'count': 291},
#  {'_id': 'Makerspaces', 'count': 91},
#  {'_id': 'Movie Theaters', 'count': 90},
#  {'_id': 'Video Art', 'count': 65},
#  {'_id': 'Rock', 'count': 2707},
#  {'_id': 'Puzzles', 'count': 95},
#  {'_id': 'Camera Equipment', 'count': 165},
#  {'_id': 'Metal', 'count': 274},
#  {'_id': 'Webseries', 'count': 2316},
#  {'_id': 'Periodicals', 'count': 517},
#  {'_id': 'Wearables', 'count': 508},
#  {'_id': 'Translations', 'count': 76},
#  {'_id': "Farmer's Markets", 'count': 175},
#  {'_id': 'Thrillers', 'count': 302},
#  {'_id': 'Academic', 'count': 367},
#  {'_id': 'Video Games', 'count': 4799},
#  {'_id': 'Animals', 'count': 97},
#  {'_id': 'Performance Art', 'count': 855},
#  {'_id': 'Comics', 'count': 1931},
#  {'_id': 'Food', 'count': 4612},
#  {'_id': 'Calendars', 'count': 112},
#  {'_id': 'Robots', 'count': 237},
#  {'_id': 'Country & Folk', 'count': 1790},
#  {'_id': 'Interactive Design', 'count': 146},
#  {'_id': 'Festivals', 'count': 313},
#  {'_id': 'Kids', 'count': 109},
#  {'_id': 'Sound', 'count': 255},
#  {'_id': 'Fabrication Tools', 'count': 96},
#  {'_id': 'Documentary', 'count': 6498},
#  {'_id': 'Technology', 'count': 2690},
#  {'_id': 'Action', 'count': 282},
#  {'_id': 'Letterpress', 'count': 24},
#  {'_id': 'Civic Design', 'count': 130},
#  {'_id': 'Comic Books', 'count': 1032},
#  {'_id': 'Woodworking', 'count': 433},
#  {'_id': 'Television', 'count': 401},
#  {'_id': 'Mobile Games', 'count': 650},
#  {'_id': 'Fantasy', 'count': 132},
#  {'_id': 'Games', 'count': 1331},
#  {'_id': 'Vegan', 'count': 229},
#  {'_id': 'Immersive', 'count': 131},
#  {'_id': 'Comedy', 'count': 923},
#  {'_id': 'Fiction', 'count': 3703},
#  {'_id': 'Dance', 'count': 901},
#  {'_id': 'Quilts', 'count': 32},
#  {'_id': 'Drinks', 'count': 995},
#  {'_id': 'Animation', 'count': 1017},
#  {'_id': 'Ceramics', 'count': 128},
#  {'_id': 'Nature', 'count': 219},
#  {'_id': 'Print', 'count': 288},
#  {'_id': 'Graphic Novels', 'count': 702},
#  {'_id': 'Embroidery', 'count': 49},
#  {'_id': 'Literary Spaces', 'count': 10},
#  {'_id': 'R&B', 'count': 172},
#  {'_id': 'Crochet', 'count': 61},
#  {'_id': 'Footwear', 'count': 379},
#  {'_id': 'Romance', 'count': 74},
#  {'_id': 'Conceptual Art', 'count': 393},
#  {'_id': 'Narrative Film', 'count': 2099},
#  {'_id': 'Radio & Podcasts', 'count': 349},
#  {'_id': 'Small Batch', 'count': 701},
#  {'_id': 'Textiles', 'count': 105},
#  {'_id': 'Webcomics', 'count': 259},
#  {'_id': 'Food Trucks', 'count': 687},
#  {'_id': '3D Printing', 'count': 271},
#  {'_id': 'Tabletop Games', 'count': 5581},
#  {'_id': 'Jewelry', 'count': 472},
#  {'_id': 'Latin', 'count': 63},
#  {'_id': 'Indie Rock', 'count': 2192},
#  {'_id': 'Video', 'count': 147},
#  {'_id': 'Punk', 'count': 127},
#  {'_id': 'Events', 'count': 322},
#  {'_id': 'Photobooks', 'count': 608},
#  {'_id': 'Graphic Design', 'count': 765},
#  {'_id': 'Shorts', 'count': 4857},
#  {'_id': 'Weaving', 'count': 38},
#  {'_id': 'Literary Journals', 'count': 118},
#  {'_id': 'Community Gardens', 'count': 115},
#  {'_id': 'Performances', 'count': 414},
#  {'_id': 'Mixed Media', 'count': 1118},
#  {'_id': 'Audio', 'count': 164},
#  {'_id': 'Architecture', 'count': 300},
#  {'_id': 'Gaming Hardware', 'count': 178},
#  {'_id': 'Poetry', 'count': 532}]

# %% [markdown]
# ## Question 4
#
# Compter le nombre de projets français ayant été instanciés avant 2016.

# %%
from datetime import datetime

cur = collection.find({"country":"FR", "launched": {"$lt" : datetime(2016, 1, 1, 0, 0, 0)}})
list(cur)
# Out:
# [{'_id': ObjectId('5fc5153592f46015ba4f6dbe'),
#   'ID': 545482362,
#   'name': 'Depeche Mode Bar Belgium',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-07-01',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 5, 27, 11, 29, 28),
#   'pledged': 305.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'FR',
#   'usd pledged': 333.98121895,
#   'usd_pledged_real': 338.42637284599937},
#  {'_id': ObjectId('5fc5153592f46015ba4f6f68'),
#   'ID': 400288569,
#   'name': 'Dracucat : A vampire kitten card game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-29',
#   'goal': 1900.0,
#   'launched': datetime.datetime(2015, 9, 29, 7, 4, 8),
#   'pledged': 2944.0,
#   'state': 'successful',
#   'backers': 129,
#   'country': 'FR',
#   'usd pledged': 3295.37237632,
#   'usd_pledged_real': 3243.3980764357875},
#  {'_id': ObjectId('5fc5153592f46015ba4f7128'),
#   'ID': 1990332786,
#   'name': 'Minotaur enjoy your life & your ice cream',
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-07-31',
#   'goal': 3800.0,
#   'launched': datetime.datetime(2015, 7, 11, 9, 19, 13),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f7168'),
#   'ID': 42552254,
#   'name': 'Catch Me',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-10-14',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 9, 19, 14, 48, 6),
#   'pledged': 226.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 257.54692190000003,
#   'usd_pledged_real': 256.73649293406646},
#  {'_id': ObjectId('5fc5153592f46015ba4f71cb'),
#   'ID': 663285707,
#   'name': 'Co-park',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-12',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 10, 13, 11, 17, 28),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f7267'),
#   'ID': 1859319535,
#   'name': 'Projet Coworking & Gaming',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-08',
#   'goal': 690000.0,
#   'launched': datetime.datetime(2015, 6, 9, 15, 33, 22),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f7556'),
#   'ID': 1946351705,
#   'name': 'Banlieues - dix ans apr?s',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-11-08',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2015, 9, 9, 11, 18, 16),
#   'pledged': 12579.0,
#   'state': 'failed',
#   'backers': 235,
#   'country': 'FR',
#   'usd pledged': 14042.99647443,
#   'usd_pledged_real': 13540.074487093929},
#  {'_id': ObjectId('5fc5153592f46015ba4f77e1'),
#   'ID': 1452688704,
#   'name': 'Jungle House',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-11-25',
#   'goal': 12000.0,
#   'launched': datetime.datetime(2015, 11, 4, 15, 41, 26),
#   'pledged': 1350.0,
#   'state': 'failed',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 1486.859463,
#   'usd_pledged_real': 1428.2993715482764},
#  {'_id': ObjectId('5fc5153592f46015ba4f7ab5'),
#   'ID': 415130131,
#   'name': 'Holystream',
#   'category': 'Faith',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2016-01-16',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 11, 27, 1, 58, 35),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f811e'),
#   'ID': 1787211494,
#   'name': 'FURCY&FAIR',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-27',
#   'goal': 9000.0,
#   'launched': datetime.datetime(2015, 6, 26, 13, 48, 57),
#   'pledged': 9392.0,
#   'state': 'successful',
#   'backers': 71,
#   'country': 'FR',
#   'usd pledged': 10525.65516128,
#   'usd_pledged_real': 10300.165601044057},
#  {'_id': ObjectId('5fc5153592f46015ba4f832b'),
#   'ID': 537199454,
#   'name': 'www.worldoo.info Moteur de Recherche',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-11',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 6, 12, 1, 10, 53),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f8640'),
#   'ID': 598062270,
#   'name': "Tonight I'll Dream About You",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-21',
#   'goal': 5900.0,
#   'launched': datetime.datetime(2015, 6, 22, 19, 17, 34),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f8c93'),
#   'ID': 1046340865,
#   'name': 'Tikiwi, a "Kiwi style" Food Truck in France!',
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-12-14',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 10, 25, 19, 27, 21),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f8d01'),
#   'ID': 630729432,
#   'name': 'Folky-Dolls... Cute LED table lamps for kids of the world!',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-20',
#   'goal': 130000.0,
#   'launched': datetime.datetime(2015, 6, 9, 6, 13, 23),
#   'pledged': 1266.0,
#   'state': 'failed',
#   'backers': 16,
#   'country': 'FR',
#   'usd pledged': 1405.16937972,
#   'usd_pledged_real': 1384.8779207140985},
#  {'_id': ObjectId('5fc5153592f46015ba4f8d84'),
#   'ID': 912757617,
#   'name': 'Siesta, Nap.',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-12-31',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 12, 1, 18, 45, 21),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.2934756,
#   'usd_pledged_real': 5.443480343592482},
#  {'_id': ObjectId('5fc5153592f46015ba4f8f80'),
#   'ID': 1515614634,
#   'name': 'Chronologia Trigalight Dive Watch',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-08-07',
#   'goal': 35500.0,
#   'launched': datetime.datetime(2015, 7, 8, 8, 20, 48),
#   'pledged': 12445.0,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'FR',
#   'usd pledged': 13734.97515005,
#   'usd_pledged_real': 13616.122714690533},
#  {'_id': ObjectId('5fc5153592f46015ba4f8fb8'),
#   'ID': 629586349,
#   'name': 'HUMANIMAGES',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-07-16',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 6, 16, 23, 30, 42),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f908c'),
#   'ID': 137985493,
#   'name': "Grandpa, How Do You Make a  Kachina? - A children's book",
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-12-18',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2015, 11, 13, 18, 5, 8),
#   'pledged': 7000.0,
#   'state': 'successful',
#   'backers': 84,
#   'country': 'FR',
#   'usd pledged': 7534.124220000002,
#   'usd_pledged_real': 7585.198027848513},
#  {'_id': ObjectId('5fc5153592f46015ba4f9538'),
#   'ID': 601724985,
#   'name': 'Shampoing MARLIVEIRA',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-10-25',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 9, 25, 20, 41, 48),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f9672'),
#   'ID': 338426049,
#   'name': 'Asterion- By director of FMA Brotherhood (Canceled)',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-28',
#   'goal': 135000.0,
#   'launched': datetime.datetime(2015, 6, 13, 11, 55, 3),
#   'pledged': 33785.0,
#   'state': 'canceled',
#   'backers': 155,
#   'country': 'FR',
#   'usd pledged': 38021.59406595,
#   'usd_pledged_real': 37051.8627375717},
#  {'_id': ObjectId('5fc5153592f46015ba4f967e'),
#   'ID': 1640048861,
#   'name': 'ARBITRELEC',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-11-30',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 10, 31, 17, 1, 23),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4f989e'),
#   'ID': 378181109,
#   'name': 'tiny & Tall: Gleipnir',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-08',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 9, 8, 9, 3, 3),
#   'pledged': 6817.0,
#   'state': 'failed',
#   'backers': 268,
#   'country': 'FR',
#   'usd pledged': 7603.20147418,
#   'usd_pledged_real': 7745.446695374547},
#  {'_id': ObjectId('5fc5153592f46015ba4f998a'),
#   'ID': 1730882800,
#   'name': '100 MECA',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-08-06',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 7, 12, 1, 47, 15),
#   'pledged': 320.0,
#   'state': 'failed',
#   'backers': 13,
#   'country': 'FR',
#   'usd pledged': 354.7722976,
#   'usd_pledged_real': 350.11323975098196},
#  {'_id': ObjectId('5fc5153592f46015ba4f9d48'),
#   'ID': 1330309415,
#   'name': 'Today is a good day',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-11',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 5, 27, 11, 6, 11),
#   'pledged': 285.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 312.08081115,
#   'usd_pledged_real': 310.3358160198615},
#  {'_id': ObjectId('5fc5153592f46015ba4fa157'),
#   'ID': 327985277,
#   'name': 'TOP SCHOOL',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-27',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 5, 28, 21, 40, 45),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fa271'),
#   'ID': 1647853204,
#   'name': 'Omega Project',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-29',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2015, 7, 30, 23, 58, 32),
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 12.18702881,
#   'usd_pledged_real': 12.25176258311707},
#  {'_id': ObjectId('5fc5153592f46015ba4fa5c3'),
#   'ID': 35689425,
#   'name': 'Eyes of India - Exhibition - Exposition - Prints - Photos',
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-10-02',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 9, 2, 0, 13, 32),
#   'pledged': 388.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'FR',
#   'usd pledged': 436.11381972,
#   'usd_pledged_real': 433.00671830011385},
#  {'_id': ObjectId('5fc5153592f46015ba4fa631'),
#   'ID': 1933641835,
#   'name': 'Body scores',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-09-15',
#   'goal': 6000.0,
#   'launched': datetime.datetime(2015, 7, 31, 9, 46, 36),
#   'pledged': 50.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 54.866071999999996,
#   'usd_pledged_real': 57.09522341360922},
#  {'_id': ObjectId('5fc5153592f46015ba4fa756'),
#   'ID': 1523608703,
#   'name': 'Marcheese',
#   'category': 'Webcomics',
#   'main_category': 'Comics',
#   'currency': 'EUR',
#   'deadline': '2015-12-24',
#   'goal': 100.0,
#   'launched': datetime.datetime(2015, 11, 14, 15, 50, 26),
#   'pledged': 126.0,
#   'state': 'successful',
#   'backers': 5,
#   'country': 'FR',
#   'usd pledged': 135.97146738,
#   'usd_pledged_real': 137.9325444175634},
#  {'_id': ObjectId('5fc5153592f46015ba4fa872'),
#   'ID': 1896558868,
#   'name': 'Mots ?crits',
#   'category': 'Spaces',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': '2015-07-16',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 6, 16, 11, 12, 17),
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'FR',
#   'usd pledged': 336.223737,
#   'usd_pledged_real': 326.66928002090685},
#  {'_id': ObjectId('5fc5153592f46015ba4fa8e1'),
#   'ID': 1040232257,
#   'name': "Lucifer's rise",
#   'category': 'Fantasy',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-11-29',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 9, 30, 17, 40, 25),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fa95f'),
#   'ID': 1673013190,
#   'name': 'LA BOX DEVINS',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-11-09',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2015, 10, 10, 20, 26, 55),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4faba1'),
#   'ID': 1115987670,
#   'name': 'TTLamp: the New Flexible, Modular & Connected Lamp',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-12-23',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 11, 24, 17, 45, 50),
#   'pledged': 398.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 422.36407148,
#   'usd_pledged_real': 435.69168792214475},
#  {'_id': ObjectId('5fc5153592f46015ba4fabd5'),
#   'ID': 1546762014,
#   'name': 'Montaign Addict :  Accessoires de ski - Ski Accesories',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-02-07',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 12, 29, 17, 27, 25),
#   'pledged': 8410.0,
#   'state': 'successful',
#   'backers': 43,
#   'country': 'FR',
#   'usd pledged': 9230.813140600001,
#   'usd_pledged_real': 9482.25319081766},
#  {'_id': ObjectId('5fc5153592f46015ba4fae38'),
#   'ID': 391218466,
#   'name': 'WHOUHAOU! Immersive installation dedicated to dance',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 27000.0,
#   'launched': datetime.datetime(2015, 5, 27, 19, 23, 5),
#   'pledged': 9200.0,
#   'state': 'failed',
#   'backers': 126,
#   'country': 'FR',
#   'usd pledged': 10074.187587999999,
#   'usd_pledged_real': 10305.813823232891},
#  {'_id': ObjectId('5fc5153592f46015ba4fae8b'),
#   'ID': 1819520246,
#   'name': 'PINGA! Even Ha?ti needs Heroes...',
#   'category': 'Events',
#   'main_category': 'Comics',
#   'currency': 'EUR',
#   'deadline': '2015-08-13',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 7, 14, 12, 44, 43),
#   'pledged': 518.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 576.46636992,
#   'usd_pledged_real': 578.6545722647959},
#  {'_id': ObjectId('5fc5153592f46015ba4faf9f'),
#   'ID': 1063655388,
#   'name': "Passions Automobiles  - Photos, tirages d'art - Art Pictures",
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-10-08',
#   'goal': 6500.0,
#   'launched': datetime.datetime(2015, 9, 18, 12, 12),
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 67.8518886,
#   'usd_pledged_real': 68.17174735550431},
#  {'_id': ObjectId('5fc5153592f46015ba4fb079'),
#   'ID': 26116111,
#   'name': "Faites revivre l'aviation fran?aise avec le HM 1000 Balerit",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-10-19',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 8, 20, 19, 44, 16),
#   'pledged': 175.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 193.30907575,
#   'usd_pledged_real': 193.97029483484815},
#  {'_id': ObjectId('5fc5153592f46015ba4fb28b'),
#   'ID': 2123383062,
#   'name': 'Ulo',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-12-04',
#   'goal': 199000.0,
#   'launched': datetime.datetime(2015, 10, 5, 15, 48, 3),
#   'pledged': 1618869.12,
#   'state': 'successful',
#   'backers': 8330,
#   'country': 'FR',
#   'usd pledged': 1815079.1817613998,
#   'usd_pledged_real': 1764896.6705187191},
#  {'_id': ObjectId('5fc5153592f46015ba4fb2d2'),
#   'ID': 456970508,
#   'name': 'oracle des reflets - oracle/tarot deck',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-06',
#   'goal': 3700.0,
#   'launched': datetime.datetime(2015, 9, 6, 21, 48, 52),
#   'pledged': 8591.0,
#   'state': 'successful',
#   'backers': 178,
#   'country': 'FR',
#   'usd pledged': 9577.76878916,
#   'usd_pledged_real': 9761.058025518958},
#  {'_id': ObjectId('5fc5153592f46015ba4fb2d7'),
#   'ID': 1302550415,
#   'name': "STARCAP 'The French Cap'",
#   'category': 'Ready-to-wear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-07-29',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2015, 5, 30, 9, 32, 56),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fb546'),
#   'ID': 1917789498,
#   'name': "Let's Coffee App - Give or Take Free Coffee, meet people !",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-12-04',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 11, 5, 19, 44, 15),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 10.949640400000002,
#   'usd_pledged_real': 10.902034319604036},
#  {'_id': ObjectId('5fc5153592f46015ba4fb78d'),
#   'ID': 1995297582,
#   'name': "Kat's Laser Crafts (Canceled)",
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-11-22',
#   'goal': 1300.0,
#   'launched': datetime.datetime(2015, 10, 14, 8, 54, 20),
#   'pledged': 30.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 34.072866,
#   'usd_pledged_real': 31.739986034406144},
#  {'_id': ObjectId('5fc5153592f46015ba4fbd67'),
#   'ID': 1871137783,
#   'name': 'Pulssy Maxxi Wireless Speaker',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 5, 27, 7, 41, 33),
#   'pledged': 151.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 165.34807889,
#   'usd_pledged_real': 169.14977035958327},
#  {'_id': ObjectId('5fc5153592f46015ba4fbd8f'),
#   'ID': 1668097693,
#   'name': 'Formation Cr?ation Couture Comme une Pro',
#   'category': 'Couture',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 5, 27, 3, 49, 36),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 10.985968699999999,
#   'usd_pledged_real': 11.201971546992269},
#  {'_id': ObjectId('5fc5153592f46015ba4fbedd'),
#   'ID': 1750798706,
#   'name': 'French Riviera Candle',
#   'category': 'Candles',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-07-28',
#   'goal': 3925.0,
#   'launched': datetime.datetime(2015, 7, 2, 16, 7, 56),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fc2a1'),
#   'ID': 1629922940,
#   'name': 'Made In France',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-06-22',
#   'goal': 600.0,
#   'launched': datetime.datetime(2015, 6, 2, 23, 51, 19),
#   'pledged': 600.0,
#   'state': 'successful',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 656.951088,
#   'usd_pledged_real': 672.1182928195362},
#  {'_id': ObjectId('5fc5153592f46015ba4fc498'),
#   'ID': 2003155960,
#   'name': 'Candle Lithophany personnalized',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-09-22',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 8, 23, 19, 59, 28),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fc551'),
#   'ID': 1455581875,
#   'name': 'monkeywi - cache-webcam ultrafin prot?ge votre vie priv?e',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-11-13',
#   'goal': 1200.0,
#   'launched': datetime.datetime(2015, 10, 9, 0, 8, 49),
#   'pledged': 3893.0,
#   'state': 'successful',
#   'backers': 318,
#   'country': 'FR',
#   'usd pledged': 4388.11543835,
#   'usd_pledged_real': 4190.437234935739},
#  {'_id': ObjectId('5fc5153592f46015ba4fc605'),
#   'ID': 1162987071,
#   'name': 'PoDDI : Intelligent Showerhead - Water savings',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-10-10',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 9, 10, 20, 6, 30),
#   'pledged': 15.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 16.771469699999994,
#   'usd_pledged_real': 17.040032716862818},
#  {'_id': ObjectId('5fc5153592f46015ba4fc7ea'),
#   'ID': 494291320,
#   'name': 'ClanSMG Serveur',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-06-27',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 5, 28, 19, 59, 1),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.4380277,
#   'usd_pledged_real': 5.547973325344252},
#  {'_id': ObjectId('5fc5153592f46015ba4fc904'),
#   'ID': 2048324945,
#   'name': 'R?ve de fer short film (Canceled)',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-07',
#   'goal': 4500.0,
#   'launched': datetime.datetime(2015, 6, 7, 12, 6, 38),
#   'pledged': 565.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 627.9145241,
#   'usd_pledged_real': 631.9557071752139},
#  {'_id': ObjectId('5fc5153592f46015ba4fcbb9'),
#   'ID': 1521723928,
#   'name': 'myGOURMET, the finest food around me',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-10-25',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 9, 25, 23, 26, 55),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fccab'),
#   'ID': 1177360909,
#   'name': 'La V?tith?que, biblioth?que de v?tements ? Bordeaux.',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-08-23',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 6, 24, 13, 45, 54),
#   'pledged': 10236.0,
#   'state': 'successful',
#   'backers': 66,
#   'country': 'FR',
#   'usd pledged': 11550.25756632,
#   'usd_pledged_real': 11533.911005442438},
#  {'_id': ObjectId('5fc5153592f46015ba4fcdfa'),
#   'ID': 1183070862,
#   'name': 'REWIND - a Short Film',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-08-03',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 7, 4, 16, 55, 12),
#   'pledged': 1098.0,
#   'state': 'successful',
#   'backers': 28,
#   'country': 'FR',
#   'usd pledged': 1217.87547858,
#   'usd_pledged_real': 1201.326053895557},
#  {'_id': ObjectId('5fc5153592f46015ba4fcee6'),
#   'ID': 1179548226,
#   'name': "Construction d'un Bikepark",
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-08-11',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 7, 12, 10, 36, 42),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fd01c'),
#   'ID': 1779919492,
#   'name': 'New light',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-12-12',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 11, 12, 6, 35, 54),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fd04e'),
#   'ID': 86530705,
#   'name': 'Nouveau jeu mobile/PC  ~~ New mobile/PC game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-12-30',
#   'goal': 3200.0,
#   'launched': datetime.datetime(2015, 10, 31, 15, 9, 19),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.09808779,
#   'usd_pledged_real': 1.088696068718496},
#  {'_id': ObjectId('5fc5153592f46015ba4fd3bc'),
#   'ID': 1302039296,
#   'name': 'SephiGame',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-12-30',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 10, 31, 18, 12, 56),
#   'pledged': 6.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 6.58852674,
#   'usd_pledged_real': 6.532176412310975},
#  {'_id': ObjectId('5fc5153592f46015ba4fd6c7'),
#   'ID': 671090174,
#   'name': 'Warn Da Nation Riddim',
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2015, 5, 27, 21, 35, 2),
#   'pledged': 32.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 35.04065248,
#   'usd_pledged_real': 35.846308950375274},
#  {'_id': ObjectId('5fc5153592f46015ba4fd6fc'),
#   'ID': 233068935,
#   'name': 'Give life to my creatures and adopt them !',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-07-26',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 5, 27, 7, 45, 57),
#   'pledged': 1538.0,
#   'state': 'successful',
#   'backers': 52,
#   'country': 'FR',
#   'usd pledged': 1684.14135982,
#   'usd_pledged_real': 1686.7179189103229},
#  {'_id': ObjectId('5fc5153592f46015ba4fdd95'),
#   'ID': 375710096,
#   'name': 'Logiciel gratuit de facturation en ligne (Control ERP)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-09',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 6, 10, 20, 34, 42),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fddfe'),
#   'ID': 1514912516,
#   'name': 'Tohu Bohu',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-12-10',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 11, 19, 15, 24, 11),
#   'pledged': 2025.0,
#   'state': 'successful',
#   'backers': 106,
#   'country': 'FR',
#   'usd pledged': 2153.251998,
#   'usd_pledged_real': 2217.379878235732},
#  {'_id': ObjectId('5fc5153592f46015ba4fded0'),
#   'ID': 163312974,
#   'name': '1 Apps for 1 life',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-23',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2015, 11, 3, 20, 54, 52),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fe016'),
#   'ID': 2044197681,
#   'name': 'Welcome to Another World!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-11-27',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 10, 21, 12, 26, 50),
#   'pledged': 10331.0,
#   'state': 'failed',
#   'backers': 206,
#   'country': 'FR',
#   'usd pledged': 11710.93450151,
#   'usd_pledged_real': 10930.193190714996},
#  {'_id': ObjectId('5fc5153592f46015ba4fe087'),
#   'ID': 1524766221,
#   'name': 'ï¿½9 Universal Remote Control App for kid mum dad grandparents',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 19000.0,
#   'launched': datetime.datetime(2015, 5, 27, 9, 28, 38),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fe2de'),
#   'ID': 204343701,
#   'name': 'ALTER WORLD',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-02',
#   'goal': 300.0,
#   'launched': datetime.datetime(2015, 7, 3, 9, 19, 40),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fe44e'),
#   'ID': 45738099,
#   'name': 'FILM COMIQUE : Un Camping Car - Mon r?ve',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-11-10',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 9, 11, 2, 32, 30),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fe469'),
#   'ID': 550753770,
#   'name': 'MaTeHyS, a powerfull all-road individual electric vehicle.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-12-05',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2015, 11, 5, 11, 44, 31),
#   'pledged': 924.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'FR',
#   'usd pledged': 1011.74677296,
#   'usd_pledged_real': 1011.7822259208972},
#  {'_id': ObjectId('5fc5153592f46015ba4fe593'),
#   'ID': 1114966662,
#   'name': 'Xculpter, the first hair and beard sculptor.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-12-10',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 11, 12, 15, 37, 14),
#   'pledged': 1039.0,
#   'state': 'failed',
#   'backers': 16,
#   'country': 'FR',
#   'usd pledged': 1118.46467332,
#   'usd_pledged_real': 1137.7075029565065},
#  {'_id': ObjectId('5fc5153592f46015ba4fe68f'),
#   'ID': 1871233881,
#   'name': 'Drops of Breath (Canceled)',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': '2015-07-27',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 6, 27, 13, 45, 7),
#   'pledged': 766.0,
#   'state': 'canceled',
#   'backers': 24,
#   'country': 'FR',
#   'usd pledged': 856.73606274,
#   'usd_pledged_real': 840.068872487196},
#  {'_id': ObjectId('5fc5153592f46015ba4feaa5'),
#   'ID': 998418451,
#   'name': 'Miami en vid?o',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-10-25',
#   'goal': 400.0,
#   'launched': datetime.datetime(2015, 9, 25, 4, 11, 49),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4fefd4'),
#   'ID': 1073912995,
#   'name': 'MIKS - When language learning becomes a game',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-07-31',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2015, 6, 16, 0, 26, 47),
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 12.39285806,
#   'usd_pledged_real': 12.063652215873573},
#  {'_id': ObjectId('5fc5153592f46015ba4ff12f'),
#   'ID': 776737905,
#   'name': 'Charlie Fly - A Mobile Action Game - iOS & Android',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-01',
#   'goal': 5600.0,
#   'launched': datetime.datetime(2015, 7, 3, 14, 26, 21),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 2.21247504,
#   'usd_pledged_real': 2.188207748443637},
#  {'_id': ObjectId('5fc5153592f46015ba4ff283'),
#   'ID': 1483086435,
#   'name': 'Le Tribunal des Songes',
#   'category': 'Fantasy',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-12-30',
#   'goal': 350.0,
#   'launched': datetime.datetime(2015, 11, 30, 20, 49, 34),
#   'pledged': 353.0,
#   'state': 'successful',
#   'backers': 12,
#   'country': 'FR',
#   'usd pledged': 373.97395389999997,
#   'usd_pledged_real': 384.30971225762886},
#  {'_id': ObjectId('5fc5153592f46015ba4ff32d'),
#   'ID': 1722631461,
#   'name': 'eResto : Restaurateurs, reprenez la maitrise !!!',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 6, 23, 22, 6, 40),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba4ff3c3'),
#   'ID': 1058418340,
#   'name': 'Le Chat et la Chouette',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-06-27',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 5, 27, 8, 0, 50),
#   'pledged': 5175.0,
#   'state': 'successful',
#   'backers': 27,
#   'country': 'FR',
#   'usd pledged': 5666.73051825,
#   'usd_pledged_real': 5742.1523917313025},
#  {'_id': ObjectId('5fc5153592f46015ba4ff51f'),
#   'ID': 1821949910,
#   'name': 'park my bike',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-09-04',
#   'goal': 9000.0,
#   'launched': datetime.datetime(2015, 8, 15, 0, 58, 28),
#   'pledged': 301.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'FR',
#   'usd pledged': 335.38351896,
#   'usd_pledged_real': 335.2527761380217},
#  {'_id': ObjectId('5fc5153592f46015ba4ff671'),
#   'ID': 166445711,
#   'name': 'Fontyou ï¿½ Simplify your typographic life',
#   'category': 'Typography',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-01',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 5, 27, 8, 38, 59),
#   'pledged': 25525.0,
#   'state': 'successful',
#   'backers': 277,
#   'country': 'FR',
#   'usd pledged': 27950.39545475,
#   'usd_pledged_real': 28322.403825882408},
#  {'_id': ObjectId('5fc5153592f46015ba4ffac0'),
#   'ID': 1121938624,
#   'name': 'Poil de carotte',
#   'category': 'Performances',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': '2015-11-24',
#   'goal': 38000.0,
#   'launched': datetime.datetime(2015, 9, 25, 11, 39, 8),
#   'pledged': 258.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 288.49701899999997,
#   'usd_pledged_real': 272.96387989589283},
#  {'_id': ObjectId('5fc5153592f46015ba500588'),
#   'ID': 27628079,
#   'name': 'Fifties Cosmetics Parfumerie Ind?pendante',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2015, 6, 9, 19, 22, 43),
#   'pledged': 3150.0,
#   'state': 'successful',
#   'backers': 36,
#   'country': 'FR',
#   'usd pledged': 3496.2745229999996,
#   'usd_pledged_real': 3430.0274402195228},
#  {'_id': ObjectId('5fc5153592f46015ba5006ba'),
#   'ID': 1674163196,
#   'name': '3d shingeki no kyojin map',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-03',
#   'goal': 350.0,
#   'launched': datetime.datetime(2015, 6, 3, 20, 29, 5),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba500a3a'),
#   'ID': 562220091,
#   'name': 'Tokyo Reverse La Suite',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-02',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 5, 27, 8, 8, 51),
#   'pledged': 944.0,
#   'state': 'failed',
#   'backers': 21,
#   'country': 'FR',
#   'usd pledged': 1033.69924816,
#   'usd_pledged_real': 1047.457363824995},
#  {'_id': ObjectId('5fc5153592f46015ba500c32'),
#   'ID': 1114030850,
#   'name': 'GOOD (OIYAA) START',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-09-05',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 8, 11, 19, 44, 17),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.09659584,
#   'usd_pledged_real': 1.1267986523488118},
#  {'_id': ObjectId('5fc5153592f46015ba500d3e'),
#   'ID': 282111032,
#   'name': 'Tunhell',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2015, 6, 14, 21, 8, 36),
#   'pledged': 9504.0,
#   'state': 'successful',
#   'backers': 459,
#   'country': 'FR',
#   'usd pledged': 10707.42936384,
#   'usd_pledged_real': 10348.88279106233},
#  {'_id': ObjectId('5fc5153592f46015ba50118d'),
#   'ID': 201728521,
#   'name': 'ALBA, a Romantic Fantasy Novel...',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2016-02-11',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 12, 13, 17, 52, 52),
#   'pledged': 72.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 79.14975552,
#   'usd_pledged_real': 81.17981328642944},
#  {'_id': ObjectId('5fc5153592f46015ba501255'),
#   'ID': 169131363,
#   'name': 'Cuisinez-vous le fran?ais?',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-11-13',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 10, 14, 14, 17, 7),
#   'pledged': 50.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 56.788109999999996,
#   'usd_pledged_real': 53.820154571483926},
#  {'_id': ObjectId('5fc5153592f46015ba501482'),
#   'ID': 1031033139,
#   'name': 'Bouteilles or vin ros? / Bottles of rose wine (Suspended)',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2016-02-14',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 12, 16, 19, 13, 18),
#   'pledged': 0.0,
#   'state': 'suspended',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba501638'),
#   'ID': 476603680,
#   'name': 'Planeta Ginga Film Festival',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-10-09',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 9, 14, 1, 51, 58),
#   'pledged': 1201.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 1361.65330228,
#   'usd_pledged_real': 1364.5711428993445},
#  {'_id': ObjectId('5fc5153592f46015ba501767'),
#   'ID': 1982275057,
#   'name': 'Casque de moto/scooter vintage en li?ge',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-01-02',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 12, 4, 11, 23),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba501a08'),
#   'ID': 355235395,
#   'name': 'Why Theatre',
#   'category': 'Spaces',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': '2015-07-21',
#   'goal': 4200.0,
#   'launched': datetime.datetime(2015, 6, 8, 9, 9, 36),
#   'pledged': 4230.0,
#   'state': 'successful',
#   'backers': 41,
#   'country': 'FR',
#   'usd pledged': 4701.0237822,
#   'usd_pledged_real': 4627.198739826727},
#  {'_id': ObjectId('5fc5153592f46015ba501ae7'),
#   'ID': 678294728,
#   'name': 'Invite-only Dating App for unique quality dates (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-12',
#   'goal': 6500.0,
#   'launched': datetime.datetime(2015, 7, 2, 16, 53, 44),
#   'pledged': 1065.0,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 1185.84072555,
#   'usd_pledged_real': 1159.6759440742196},
#  {'_id': ObjectId('5fc5153592f46015ba501bba'),
#   'ID': 1678794458,
#   'name': 'Polaroids from France',
#   'category': 'Places',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-09-20',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 8, 31, 18, 25, 35),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 11.1819175,
#   'usd_pledged_real': 11.151006935926313},
#  {'_id': ObjectId('5fc5153592f46015ba501fcb'),
#   'ID': 2029690838,
#   'name': 'Ambasdr.  Learn to the world how to use social media.',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-11',
#   'goal': 3500.0,
#   'launched': datetime.datetime(2015, 10, 12, 7, 59, 29),
#   'pledged': 2007.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 2279.7362475,
#   'usd_pledged_real': 2160.3410044993648},
#  {'_id': ObjectId('5fc5153592f46015ba502024'),
#   'ID': 208665246,
#   'name': "'' Album''Eyes to Eyes''of Kilimandjaro' '",
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2016-01-31',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 12, 6, 22, 52, 38),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153592f46015ba502253'),
#   'ID': 1159985516,
#   'name': '888bijouï¿½ le cadeau id?al : design, chance, amour et chic',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 2888.0,
#   'launched': datetime.datetime(2015, 5, 27, 7, 37, 47),
#   'pledged': 3336.0,
#   'state': 'successful',
#   'backers': 34,
#   'country': 'FR',
#   'usd pledged': 3652.98802104,
#   'usd_pledged_real': 3632.5623938324843},
#  {'_id': ObjectId('5fc5153592f46015ba50225f'),
#   'ID': 2103464588,
#   'name': 'Wings of Justice',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-09-13',
#   'goal': 2200.0,
#   'launched': datetime.datetime(2015, 8, 10, 16, 30, 18),
#   'pledged': 556.0,
#   'state': 'failed',
#   'backers': 32,
#   'country': 'FR',
#   'usd pledged': 609.7246676,
#   'usd_pledged_real': 634.8988843593345},
#  {'_id': ObjectId('5fc5153592f46015ba502442'),
#   'ID': 1254718606,
#   'name': "Heart of Ice gamebook Collector's Edition (English / French)",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-09-10',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 8, 26, 15, 18, 49),
#   'pledged': 4654.0,
#   'state': 'successful',
#   'backers': 125,
#   'country': 'FR',
#   'usd pledged': 5367.8672866000015,
#   'usd_pledged_real': 5244.120928031371},
#  {'_id': ObjectId('5fc5153592f46015ba50269d'),
#   'ID': 1740138844,
#   'name': 'Abaros - Leather Belt',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-12-29',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 11, 24, 15, 46, 50),
#   'pledged': 15289.0,
#   'state': 'successful',
#   'backers': 175,
#   'country': 'FR',
#   'usd pledged': 16224.93539914,
#   'usd_pledged_real': 16645.074194637084},
#  {'_id': ObjectId('5fc5153592f46015ba502754'),
#   'ID': 824679072,
#   'name': 'Custom boxwood dice made in Jura',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-11-06',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2015, 10, 7, 0, 41, 31),
#   'pledged': 365.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 410.27785215,
#   'usd_pledged_real': 396.53655197888037},
#  {'_id': ObjectId('5fc5153592f46015ba502833'),
#   'ID': 436973805,
#   'name': "My 2016, l'agenda de votre ann?e",
#   'category': 'Calendars',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-12-02',
#   'goal': 1200.0,
#   'launched': datetime.datetime(2015, 11, 10, 0, 2),
#   'pledged': 1767.0,
#   'state': 'successful',
#   'backers': 69,
#   'country': 'FR',
#   'usd pledged': 1897.96733649,
#   'usd_pledged_real': 1926.3894642740336},
#  {'_id': ObjectId('5fc5153592f46015ba5028dd'),
#   'ID': 1707789341,
#   'name': 'New World Vision',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-11',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 10, 2, 20, 31, 4),
#   'pledged': 31.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 34.61100028,
#   'usd_pledged_real': 33.368495834320036},
#  {'_id': ObjectId('5fc5153592f46015ba502a17'),
#   'ID': 1807647480,
#   'name': 'DONUTS FACTORY',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 90000.0,
#   'launched': datetime.datetime(2015, 6, 9, 15, 39, 20),
#   'pledged': 192.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'FR',
#   'usd pledged': 213.10625664,
#   'usd_pledged_real': 209.0683392133804},
#  {'_id': ObjectId('5fc5153592f46015ba502db8'),
#   'ID': 504259167,
#   'name': '"les recettes" : world food drawing and recipe on shirt',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-11-13',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 9, 24, 1, 19, 59),
#   'pledged': 130.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 145.6372138,
#   'usd_pledged_real': 139.9324018858582},
#  {'_id': ObjectId('5fc5153592f46015ba50334d'),
#   'ID': 1711978703,
#   'name': 'TikiOne Steam Cleaner (Canceled)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-10-02',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 8, 3, 22, 9, 21),
#   'pledged': 163.0,
#   'state': 'canceled',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 179.15552821,
#   'usd_pledged_real': 181.9074615539138},
#  {'_id': ObjectId('5fc5153592f46015ba503656'),
#   'ID': 414964217,
#   'name': 'Youfigure3D',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-19',
#   'goal': 44.0,
#   'launched': datetime.datetime(2015, 6, 24, 12, 5, 24),
#   'pledged': 446.0,
#   'state': 'successful',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 503.26444652,
#   'usd_pledged_real': 487.8795834427234},
#  {'_id': ObjectId('5fc5153592f46015ba50389d'),
#   'ID': 2094487330,
#   'name': 'TPT (Tunisian Public Transport)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-01',
#   'goal': 1546.0,
#   'launched': datetime.datetime(2015, 7, 2, 15, 11, 18),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.56732735,
#   'usd_pledged_real': 5.470519371109092},
#  {'_id': ObjectId('5fc5153592f46015ba503d6a'),
#   'ID': 18939379,
#   'name': 'The Reversible Tie - La Cravate R?versible | Oh My Node',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 5, 27, 6, 25, 25),
#   'pledged': 10968.0,
#   'state': 'successful',
#   'backers': 100,
#   'country': 'FR',
#   'usd pledged': 12010.18363752,
#   'usd_pledged_real': 12286.322392741124},
#  {'_id': ObjectId('5fc5153592f46015ba503df7'),
#   'ID': 1152345794,
#   'name': 'CREOLE SOUL',
#   'category': 'Ready-to-wear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-01-14',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 11, 25, 20, 53, 40),
#   'pledged': 525.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 558.25882875,
#   'usd_pledged_real': 572.9877216916782},
#  {'_id': ObjectId('5fc5153592f46015ba504294'),
#   'ID': 279280557,
#   'name': 'Zmei - Leather Goods & Accessories for Apple Watch & iPhone',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2016-01-15',
#   'goal': 6500.0,
# ...
#   'ID': 2118888011,
#   'name': 'LUNA - Luxury Sleep Mask with NAP & Lucid Dream Features',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-03',
#   'goal': '25000.0',
#   'launched': datetime.datetime(2015, 5, 29, 2, 9, 24),
#   'pledged': '13072.0',
#   'state': 'canceled',
#   'backers': '120',
#   'country': 'FR',
#   'usd pledged': '14217.17961888',
#   'usd_pledged_real': 14504.621461780012},
#  {'_id': ObjectId('5fc5153792f46015ba516e8a'),
#   'ID': 1556193939,
#   'name': 'The Album To Support French community for black friday',
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2016-01-13',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 11, 14, 17, 2, 3),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153792f46015ba51725a'),
#   'ID': 977207362,
#   'name': 'Zoby Z?',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-09-05',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 7, 22, 22, 33, 19),
#   'pledged': 292.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 316.24971232,
#   'usd_pledged_real': 329.02520648585306},
#  {'_id': ObjectId('5fc5153792f46015ba5179d2'),
#   'ID': 1325039752,
#   'name': 'No Gig Impossible : uchronian dream gigs, collector posters.',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-12-25',
#   'goal': 9710.0,
#   'launched': datetime.datetime(2015, 11, 25, 18, 36, 29),
#   'pledged': 125.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 132.91876875,
#   'usd_pledged_real': 136.087008589812},
#  {'_id': ObjectId('5fc5153792f46015ba517bed'),
#   'ID': 197599880,
#   'name': 'THE DEVIL DOGS',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-27',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 5, 28, 21, 11, 25),
#   'pledged': 30320.0,
#   'state': 'successful',
#   'backers': 105,
#   'country': 'FR',
#   'usd pledged': 32976.1999728,
#   'usd_pledged_real': 33251.81228957152},
#  {'_id': ObjectId('5fc5153792f46015ba517c11'),
#   'ID': 2018078323,
#   'name': 'Kitchen Trotter : un voyage ? cuisiner - a trip to cook !',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-07-10',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 5, 27, 8, 12, 55),
#   'pledged': 20689.0,
#   'state': 'successful',
#   'backers': 359,
#   'country': 'FR',
#   'usd pledged': 22654.87684871,
#   'usd_pledged_real': 23140.763939377},
#  {'_id': ObjectId('5fc5153792f46015ba517cf7'),
#   'ID': 813865095,
#   'name': 'Komodor: V?tements graphiques de qualit? design?s en France',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-10-14',
#   'goal': 5500.0,
#   'launched': datetime.datetime(2015, 9, 14, 10, 0, 52),
#   'pledged': 1642.0,
#   'state': 'failed',
#   'backers': 31,
#   'country': 'FR',
#   'usd pledged': 1861.64423176,
#   'usd_pledged_real': 1865.3155814059164},
#  {'_id': ObjectId('5fc5153792f46015ba517d3d'),
#   'ID': 1593053116,
#   'name': 'The Prophecy of Amat (Canceled)',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-12-06',
#   'goal': 6000.0,
#   'launched': datetime.datetime(2015, 11, 6, 15, 5, 17),
#   'pledged': 680.0,
#   'state': 'canceled',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 739.2469447999997,
#   'usd_pledged_real': 744.6016381236038},
#  {'_id': ObjectId('5fc5153792f46015ba5181e0'),
#   'ID': 1878604968,
#   'name': 'VARIATIONS',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-10-24',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 9, 21, 21, 59, 22),
#   'pledged': 12.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 13.56407328,
#   'usd_pledged_real': 13.220372594167616},
#  {'_id': ObjectId('5fc5153792f46015ba518493'),
#   'ID': 530682273,
#   'name': 'Rendons ? Marie-Antoinette...son ?pinette',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-10-14',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 8, 30, 16, 34, 53),
#   'pledged': 51.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 57.02777925,
#   'usd_pledged_real': 57.93611123733358},
#  {'_id': ObjectId('5fc5153792f46015ba5187b7'),
#   'ID': 726258998,
#   'name': 'Customisation Sneakers',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-11-09',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 9, 23, 9, 41, 17),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153792f46015ba5189db'),
#   'ID': 1388326878,
#   'name': 'REFLEXION CONTRE NATURE',
#   'category': 'Nature',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-07-05',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 6, 14, 21, 6, 23),
#   'pledged': 2519.0,
#   'state': 'successful',
#   'backers': 22,
#   'country': 'FR',
#   'usd pledged': 2837.96449574,
#   'usd_pledged_real': 2817.5157988926794},
#  {'_id': ObjectId('5fc5153792f46015ba518c52'),
#   'ID': 679439475,
#   'name': 'SOLAR KIT BOX & BATTERY UNIT: Save On Your Electricity Bill!',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-23',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 6, 23, 23, 40, 42),
#   'pledged': 8683.0,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'FR',
#   'usd pledged': 9878.93381557,
#   'usd_pledged_real': 9498.337271374814},
#  {'_id': ObjectId('5fc5153792f46015ba518ee5'),
#   'ID': 148873286,
#   'name': 'Ride Europe and USA to Dance the World',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-08-26',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 8, 11, 19, 29, 52),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153792f46015ba51912c'),
#   'ID': 1674716636,
#   'name': 'Aller voir mes 2 seuls amis en suisse',
#   'category': 'Nature',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2016-01-18',
#   'goal': 1100.0,
#   'launched': datetime.datetime(2015, 11, 19, 4, 38, 55),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153792f46015ba519554'),
#   'ID': 781355584,
#   'name': 'Reportage sur Mr Mickey Mouse',
#   'category': 'Video',
#   'main_category': 'Journalism',
#   'currency': 'EUR',
#   'deadline': '2015-06-30',
#   'goal': 400.0,
#   'launched': datetime.datetime(2015, 6, 21, 18, 33, 41),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153792f46015ba5195ba'),
#   'ID': 916472687,
#   'name': 'Imprimerie 3D - Fablab en zone rurale',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-31',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2015, 6, 18, 16, 21, 51),
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 112.539867,
#   'usd_pledged_real': 109.66956559885062},
#  {'_id': ObjectId('5fc5153792f46015ba519704'),
#   'ID': 263025244,
#   'name': 'UnitMaker',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-09-18',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2015, 8, 19, 8, 38, 19),
#   'pledged': 85.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 94.16383640000001,
#   'usd_pledged_real': 97.06187980313568},
#  {'_id': ObjectId('5fc5153792f46015ba519979'),
#   'ID': 2101577594,
#   'name': 'Cold Blooded',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-07-22',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 6, 22, 11, 49, 13),
#   'pledged': 517.0,
#   'state': 'failed',
#   'backers': 34,
#   'country': 'FR',
#   'usd pledged': 586.9197521000001,
#   'usd_pledged_real': 565.5465126454887},
#  {'_id': ObjectId('5fc5153792f46015ba5199c1'),
#   'ID': 2146589298,
#   'name': 'Tutoriel complet Aquarium Juwel 450 vision ultra plant?',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-12-22',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2015, 10, 23, 0, 28, 25),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153792f46015ba519b51'),
#   'ID': 831858023,
#   'name': 'Deleez Cookies (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-12-16',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 11, 16, 21, 35, 20),
#   'pledged': 86.0,
#   'state': 'canceled',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 92.6326855,
#   'usd_pledged_real': 93.18957577071028},
#  {'_id': ObjectId('5fc5153792f46015ba519beb'),
#   'ID': 1887864427,
#   'name': 'The First International B2B Networking Platform.',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-05',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 7, 6, 18, 31, 59),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153792f46015ba519c1f'),
#   'ID': 1316370878,
#   'name': 'MUSE DELTA',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-21',
#   'goal': 90000.0,
#   'launched': datetime.datetime(2015, 10, 22, 18, 20, 58),
#   'pledged': 1415.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'FR',
#   'usd pledged': 1607.249541,
#   'usd_pledged_real': 1497.0693412894898},
#  {'_id': ObjectId('5fc5153792f46015ba51a24e'),
#   'ID': 1089062782,
#   'name': 'APPARENCES: a photography project about people and light',
#   'category': 'People',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-09-21',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 8, 7, 23, 40, 19),
#   'pledged': 2108.0,
#   'state': 'successful',
#   'backers': 25,
#   'country': 'FR',
#   'usd pledged': 2298.77286168,
#   'usd_pledged_real': 2350.632262093267},
#  {'_id': ObjectId('5fc5153792f46015ba51a253'),
#   'ID': 1327570430,
#   'name': 'r?n',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-18',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2015, 6, 18, 17, 55, 55),
#   'pledged': 86.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 96.78428562,
#   'usd_pledged_real': 94.0754353723637},
#  {'_id': ObjectId('5fc5153792f46015ba51a26c'),
#   'ID': 1033114039,
#   'name': 'C&G (Canceled)',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-07-13',
#   'goal': 29000.0,
#   'launched': datetime.datetime(2015, 6, 5, 12, 45, 16),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc5153792f46015ba51a319'),
#   'ID': 109832866,
#   'name': 'New PC Game Hit Tank PRO Steam Greenlight Need help !!!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-11-14',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2015, 10, 15, 17, 41, 34),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.13906244,
#   'usd_pledged_real': 1.0687985635347306},
#  {'_id': ObjectId('5fc5153792f46015ba51a440'),
#   'ID': 688601772,
#   'name': 'Stephen Hawking Hologram Project',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-09-15',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 7, 21, 9, 16, 56),
#   'pledged': 1108.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'FR',
#   'usd pledged': 1199.44315136,
#   'usd_pledged_real': 1265.2301508455805},
#  {'_id': ObjectId('5fc5153792f46015ba51a451'),
#   'ID': 205663955,
#   'name': "Cr?ation d'un atelier de costume ind?pendant",
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-08-26',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2015, 7, 27, 18, 20, 54),
#   'pledged': 1841.0,
#   'state': 'successful',
#   'backers': 26,
#   'country': 'FR',
#   'usd pledged': 2021.37985448,
#   'usd_pledged_real': 2074.4363189741625},
#  {'_id': ObjectId('5fc5153792f46015ba51a486'),
#   'ID': 1170494966,
#   'name': 'a Family of Grave Diggers (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-09',
#   'goal': 6000.0,
#   'launched': datetime.datetime(2015, 7, 11, 18, 7, 55),
#   'pledged': 174.0,
#   'state': 'canceled',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 192.90743682,
#   'usd_pledged_real': 194.37431578006652},
#  {'_id': ObjectId('5fc5153792f46015ba51a713'),
#   'ID': 587734625,
#   'name': 'The Bakounines (2016) - 2nd EP !',
#   'category': 'Punk',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-12-13',
#   'goal': 700.0,
#   'launched': datetime.datetime(2015, 10, 19, 14, 12, 14),
#   'pledged': 770.0,
#   'state': 'successful',
#   'backers': 14,
#   'country': 'FR',
#   'usd pledged': 873.8669555,
#   'usd_pledged_real': 834.3717830633365},
#  {'_id': ObjectId('5fc5153792f46015ba51add4'),
#   'ID': 83153281,
#   'name': 'Wram - Handcrafted full grain leather wallet and card-holder',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-11-07',
#   'goal': 1200.0,
#   'launched': datetime.datetime(2015, 10, 8, 15, 39, 54),
#   'pledged': 3685.0,
#   'state': 'successful',
#   'backers': 104,
#   'country': 'FR',
#   'usd pledged': 4153.66180075,
#   'usd_pledged_real': 3966.5453919183656},
#  {'_id': ObjectId('5fc5153792f46015ba51b0aa'),
#   'ID': 12134418,
#   'name': 'New AMIGA 1200 Cases (Made From New Molds)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-11-01',
#   'goal': 125000.0,
#   'launched': datetime.datetime(2015, 9, 2, 12, 0, 19),
#   'pledged': 156310.02,
#   'state': 'successful',
#   'backers': 840,
#   'country': 'FR',
#   'usd pledged': 176145.799052405,
#   'usd_pledged_real': 169815.44211109538},
#  {'_id': ObjectId('5fc5153792f46015ba51b1e9'),
#   'ID': 508223995,
#   'name': 'Sijak Taekwondo Card Game / Jeu de Cartes (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-12-14',
#   'goal': 6500.0,
#   'launched': datetime.datetime(2015, 11, 21, 18, 20, 23),
#   'pledged': 1340.0,
#   'state': 'canceled',
#   'backers': 28,
#   'country': 'FR',
#   'usd pledged': 1435.6117470000006,
#   'usd_pledged_real': 1452.0236224738587},
#  {'_id': ObjectId('5fc5153792f46015ba51b296'),
#   'ID': 299205964,
#   'name': '10 ans de Mariage ! - Spectacle com?die au Qu?bec (Canceled)',
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': '2015-10-05',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 9, 9, 19, 37, 12),
#   'pledged': 130.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 145.1299421,
#   'usd_pledged_real': 147.70545260359262},
#  {'_id': ObjectId('5fc5153792f46015ba51b3c6'),
#   'ID': 1115857606,
#   'name': 'Saint-Matthieu',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-08-19',
#   'goal': 99.0,
#   'launched': datetime.datetime(2015, 7, 20, 20, 49, 42),
#   'pledged': 100.0,
#   'state': 'successful',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 108.29918300000001,
#   'usd_pledged_real': 112.80952112358284}]

# %%
cur = collection.find({"country":"FR"})
list(cur)
# Out:
# [{'_id': ObjectId('5fc4e26492f46015ba464496'),
#   'ID': 1131677007,
#   'name': 'Bittersweet',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2016-02-04',
#   'goal': 2000.0,
#   'launched': '2016-01-05 06:00:18',
#   'pledged': 2293.0,
#   'state': 'successful',
#   'backers': 44,
#   'country': 'FR',
#   'usd pledged': 2492.60262324,
#   'usd_pledged_real': 2568.6120757253275},
#  {'_id': ObjectId('5fc4e26492f46015ba4645fa'),
#   'ID': 545482362,
#   'name': 'Depeche Mode Bar Belgium',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-07-01',
#   'goal': 20000.0,
#   'launched': '2015-05-27 11:29:28',
#   'pledged': 305.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'FR',
#   'usd pledged': 333.98121895,
#   'usd_pledged_real': 338.42637284599937},
#  {'_id': ObjectId('5fc4e26492f46015ba464634'),
#   'ID': 1442243866,
#   'name': "GOB'Z'HEROES - The Game",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-01-31',
#   'goal': 30000.0,
#   'launched': '2016-01-05 13:46:06',
#   'pledged': 74024.0,
#   'state': 'successful',
#   'backers': 566,
#   'country': 'FR',
#   'usd pledged': 80467.69148832,
#   'usd_pledged_real': 82921.47417945557},
#  {'_id': ObjectId('5fc4e26492f46015ba464775'),
#   'ID': 1084370615,
#   'name': 'Me and the sea around the world',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2016-04-05',
#   'goal': 8000.0,
#   'launched': '2016-03-06 16:36:44',
#   'pledged': 14.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 15.40794738,
#   'usd_pledged_real': 15.908187034827563},
#  {'_id': ObjectId('5fc4e26492f46015ba464776'),
#   'ID': 417652056,
#   'name': "Le jeu de l'amour",
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-02-07',
#   'goal': 10000.0,
#   'launched': '2016-02-01 13:35:30',
#   'pledged': 1857.0,
#   'state': 'failed',
#   'backers': 84,
#   'country': 'FR',
#   'usd pledged': 2011.27047927,
#   'usd_pledged_real': 2093.762684345826},
#  {'_id': ObjectId('5fc4e26492f46015ba4647a4'),
#   'ID': 400288569,
#   'name': 'Dracucat : A vampire kitten card game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-29',
#   'goal': 1900.0,
#   'launched': '2015-09-29 07:04:08',
#   'pledged': 2944.0,
#   'state': 'successful',
#   'backers': 129,
#   'country': 'FR',
#   'usd pledged': 3295.37237632,
#   'usd_pledged_real': 3243.3980764357875},
#  {'_id': ObjectId('5fc4e26492f46015ba4647f3'),
#   'ID': 1206788532,
#   'name': 'Hunt Me Down',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-03-30',
#   'goal': 15000.0,
#   'launched': '2017-02-18 09:03:23',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba46480a'),
#   'ID': 1168114065,
#   'name': 'BLACK-LINE',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2018-01-02',
#   'goal': 15000.0,
#   'launched': '2017-11-28 23:59:36',
#   'pledged': 5115.0,
#   'state': 'live',
#   'backers': 29,
#   'country': 'FR',
#   'usd pledged': 166.93455659999995,
#   'usd_pledged_real': 6161.017561610176},
#  {'_id': ObjectId('5fc4e26492f46015ba464892'),
#   'ID': 1975125384,
#   'name': 'Easy Flip Grill - The Revolution',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-08-13',
#   'goal': 50000.0,
#   'launched': '2017-07-10 11:56:17',
#   'pledged': 1012.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 490.2631455,
#   'usd_pledged_real': 1188.0862653940524},
#  {'_id': ObjectId('5fc4e26492f46015ba464924'),
#   'ID': 1514206440,
#   'name': 'Blockchain Worldwide : la fabrication distribu?e',
#   'category': 'Makerspaces',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-08-19',
#   'goal': 8000.0,
#   'launched': '2016-06-20 15:21:52',
#   'pledged': 8267.0,
#   'state': 'successful',
#   'backers': 27,
#   'country': 'FR',
#   'usd pledged': 315.7348740000001,
#   'usd_pledged_real': 9363.249218502242},
#  {'_id': ObjectId('5fc4e26492f46015ba464964'),
#   'ID': 1990332786,
#   'name': 'Minotaur enjoy your life & your ice cream',
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-07-31',
#   'goal': 3800.0,
#   'launched': '2015-07-11 09:19:13',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba4649a4'),
#   'ID': 42552254,
#   'name': 'Catch Me',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-10-14',
#   'goal': 20000.0,
#   'launched': '2015-09-19 14:48:06',
#   'pledged': 226.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 257.54692190000003,
#   'usd_pledged_real': 256.73649293406646},
#  {'_id': ObjectId('5fc4e26492f46015ba4649d7'),
#   'ID': 1778881226,
#   'name': 'Organic Protein Pills & Powders made with Alga',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2017-05-21',
#   'goal': 10000.0,
#   'launched': '2017-03-22 10:56:26',
#   'pledged': 21.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 43.0242152,
#   'usd_pledged_real': 23.511498242235607},
#  {'_id': ObjectId('5fc4e26492f46015ba4649f0'),
#   'ID': 1719039742,
#   'name': 'Jingwei Agency: ?diter nos premiers livres en juin 2017',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2017-04-20',
#   'goal': 6000.0,
#   'launched': '2017-03-06 12:17:52',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0698047606311851},
#  {'_id': ObjectId('5fc4e26492f46015ba464a07'),
#   'ID': 663285707,
#   'name': 'Co-park',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-12',
#   'goal': 2500.0,
#   'launched': '2015-10-13 11:17:28',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba464a51'),
#   'ID': 1441215966,
#   'name': 'Rapide et Furieux',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-10-23',
#   'goal': 4000.0,
#   'launched': '2017-09-23 13:12:04',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 11.957188499999999,
#   'usd_pledged_real': 11.60496692584426},
#  {'_id': ObjectId('5fc4e26492f46015ba464a5c'),
#   'ID': 449401364,
#   'name': 'Just after midnight',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2017-02-02',
#   'goal': 3000.0,
#   'launched': '2017-01-03 11:08:49',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba464aa3'),
#   'ID': 1859319535,
#   'name': 'Projet Coworking & Gaming',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-08',
#   'goal': 690000.0,
#   'launched': '2015-06-09 15:33:22',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba464b27'),
#   'ID': 992693653,
#   'name': 'VASCO WATCH | NEW 24H TIMEPIECES',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-07-20',
#   'goal': 16000.0,
#   'launched': '2017-06-15 20:05:48',
#   'pledged': 54830.0,
#   'state': 'successful',
#   'backers': 286,
#   'country': 'FR',
#   'usd pledged': 24705.88235241,
#   'usd_pledged_real': 63833.00735773494},
#  {'_id': ObjectId('5fc4e26492f46015ba464b2c'),
#   'ID': 158793161,
#   'name': 'The 1st Luxury Brand dedicated to the rare Guanaco Fibre.',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-10-20',
#   'goal': 27500.0,
#   'launched': '2016-09-05 09:40:04',
#   'pledged': 30902.0,
#   'state': 'successful',
#   'backers': 142,
#   'country': 'FR',
#   'usd pledged': 987.39261495,
#   'usd_pledged_real': 33639.95602050925},
#  {'_id': ObjectId('5fc4e26492f46015ba464b7d'),
#   'ID': 2032737108,
#   'name': 'One Metro World - Follow Up',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2016-12-01',
#   'goal': 100.0,
#   'launched': '2016-10-27 13:42:33',
#   'pledged': 5954.0,
#   'state': 'successful',
#   'backers': 104,
#   'country': 'FR',
#   'usd pledged': 455.21372072,
#   'usd_pledged_real': 6336.266987346622},
#  {'_id': ObjectId('5fc4e26492f46015ba464bf5'),
#   'ID': 1433514155,
#   'name': 'Topvirtuel ! Vendez, louez vite et bien!',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-09-18',
#   'goal': 100000.0,
#   'launched': '2016-08-09 19:13:25',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba464c0c'),
#   'ID': 1640855222,
#   'name': 'Rare Craft Matcha Green Tea from Japan',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2017-11-26',
#   'goal': 8000.0,
#   'launched': '2017-09-27 15:43:50',
#   'pledged': 111734.0,
#   'state': 'successful',
#   'backers': 1314,
#   'country': 'FR',
#   'usd pledged': 432.93278165,
#   'usd_pledged_real': 132795.3410981697},
#  {'_id': ObjectId('5fc4e26492f46015ba464c66'),
#   'ID': 1648437585,
#   'name': 'Wouai: your virtual personal concierge',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-02-08',
#   'goal': 10000.0,
#   'launched': '2017-01-09 20:55:59',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 26.572564358750878},
#  {'_id': ObjectId('5fc4e26492f46015ba464d27'),
#   'ID': 1314462351,
#   'name': 'CROSSFIT EST-VAR',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2016-11-27',
#   'goal': 10000.0,
#   'launched': '2016-10-28 11:45:19',
#   'pledged': 515.0,
#   'state': 'failed',
#   'backers': 9,
#   'country': 'FR',
#   'usd pledged': 490.35632400000003,
#   'usd_pledged_real': 548.0647461342811},
#  {'_id': ObjectId('5fc4e26492f46015ba464d92'),
#   'ID': 1946351705,
#   'name': 'Banlieues - dix ans apr?s',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-11-08',
#   'goal': 40000.0,
#   'launched': '2015-09-09 11:18:16',
#   'pledged': 12579.0,
#   'state': 'failed',
#   'backers': 235,
#   'country': 'FR',
#   'usd pledged': 14042.99647443,
#   'usd_pledged_real': 13540.074487093929},
#  {'_id': ObjectId('5fc4e26492f46015ba464d9d'),
#   'ID': 1678091760,
#   'name': 'MUSKETEER CHESS, CHESS REVOLUTION (MODERN DESIGN, COMPUTER)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-05-26',
#   'goal': 6000.0,
#   'launched': '2016-03-28 12:24:31',
#   'pledged': 101.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 112.78439013,
#   'usd_pledged_real': 112.79622970226265},
#  {'_id': ObjectId('5fc4e26492f46015ba464e53'),
#   'ID': 334204927,
#   'name': 'Renewable energy marketing plateform',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-04-15',
#   'goal': 1000000.0,
#   'launched': '2016-03-16 09:18:09',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 2.22198522,
#   'usd_pledged_real': 2.2568014353257126},
#  {'_id': ObjectId('5fc4e26492f46015ba464f71'),
#   'ID': 898682767,
#   'name': 'CMore, application de tourisme',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-03-23',
#   'goal': 3000.0,
#   'launched': '2017-02-06 17:42:01',
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 108.04970286331712},
#  {'_id': ObjectId('5fc4e26492f46015ba464fa7'),
#   'ID': 542203107,
#   'name': 'A woman in a mans body.',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2017-02-28',
#   'goal': 500000.0,
#   'launched': '2017-02-03 08:52:55',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba465019'),
#   'ID': 1914849242,
#   'name': 'Roman science fiction : Imperium Genesis T2 - Sci fi ebook',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2016-09-11',
#   'goal': 2500.0,
#   'launched': '2016-08-12 15:42:09',
#   'pledged': 2.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.245198082600837},
#  {'_id': ObjectId('5fc4e26492f46015ba46501d'),
#   'ID': 1452688704,
#   'name': 'Jungle House',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-11-25',
#   'goal': 12000.0,
#   'launched': '2015-11-04 15:41:26',
#   'pledged': 1350.0,
#   'state': 'failed',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 1486.859463,
#   'usd_pledged_real': 1428.2993715482764},
#  {'_id': ObjectId('5fc4e26492f46015ba465099'),
#   'ID': 310385805,
#   'name': "Help fund Pembroke's debut album!",
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2016-06-25',
#   'goal': 3000.0,
#   'launched': '2016-05-25 10:47:15',
#   'pledged': 5200.0,
#   'state': 'successful',
#   'backers': 135,
#   'country': 'FR',
#   'usd pledged': 5694.6140108,
#   'usd_pledged_real': 5790.194528266171},
#  {'_id': ObjectId('5fc4e26492f46015ba4650f5'),
#   'ID': 947218654,
#   'name': 'Qi Wireless Battery for X-Box One / One S Gamepad',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-07-27',
#   'goal': 20000.0,
#   'launched': '2017-06-27 17:42:15',
#   'pledged': 616.0,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'FR',
#   'usd pledged': 128.75978565,
#   'usd_pledged_real': 722.5043690402186},
#  {'_id': ObjectId('5fc4e26492f46015ba46513e'),
#   'ID': 1587414933,
#   'name': 'C!RCUS Magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2017-03-17',
#   'goal': 700.0,
#   'launched': '2017-02-15 21:47:23',
#   'pledged': 1023.0,
#   'state': 'successful',
#   'backers': 42,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1098.393746778904},
#  {'_id': ObjectId('5fc4e26492f46015ba4651d9'),
#   'ID': 1148653845,
#   'name': "AromaCare, the world's 1st connected essential oil diffuser",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-02-13',
#   'goal': 55000.0,
#   'launched': '2016-01-06 17:59:10',
#   'pledged': 4912.0,
#   'state': 'canceled',
#   'backers': 59,
#   'country': 'FR',
#   'usd pledged': 5314.55637792,
#   'usd_pledged_real': 5450.328994818193},
#  {'_id': ObjectId('5fc4e26492f46015ba4651e0'),
#   'ID': 199910676,
#   'name': 'NASA Graphic Standards Manual / Norme graphique de la NASA',
#   'category': 'Translations',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2016-04-16',
#   'goal': 8500.0,
#   'launched': '2016-03-07 17:27:13',
#   'pledged': 9480.0,
#   'state': 'successful',
#   'backers': 258,
#   'country': 'FR',
#   'usd pledged': 10433.3815116,
#   'usd_pledged_real': 10677.35904309238},
#  {'_id': ObjectId('5fc4e26492f46015ba4652f1'),
#   'ID': 415130131,
#   'name': 'Holystream',
#   'category': 'Faith',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2016-01-16',
#   'goal': 25000.0,
#   'launched': '2015-11-27 01:58:35',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba465370'),
#   'ID': 332720503,
#   'name': 'Black Box By B.Studio',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2016-11-10',
#   'goal': 25000.0,
#   'launched': '2016-09-11 14:22:31',
#   'pledged': 1600.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1744.6488349017002},
#  {'_id': ObjectId('5fc4e26492f46015ba465382'),
#   'ID': 57444727,
#   'name': 'Seahorse Tool - A multifunctional keychain',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-05-27',
#   'goal': 11900.0,
#   'launched': '2017-04-12 18:56:39',
#   'pledged': 2143.0,
#   'state': 'failed',
#   'backers': 127,
#   'country': 'FR',
#   'usd pledged': 658.41774546,
#   'usd_pledged_real': 2403.813796971397},
#  {'_id': ObjectId('5fc4e26492f46015ba4654f1'),
#   'ID': 569558249,
#   'name': 'DamyWay POWER TEKSUITï¿½',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-10-16',
#   'goal': 15000.0,
#   'launched': '2017-09-11 13:46:19',
#   'pledged': 527.0,
#   'state': 'canceled',
#   'backers': 5,
#   'country': 'FR',
#   'usd pledged': 574.07630202,
#   'usd_pledged_real': 622.8062918798822},
#  {'_id': ObjectId('5fc4e26492f46015ba465548'),
#   'ID': 1644379965,
#   'name': 'B. Life - The life-saving Bracelet',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-10-24',
#   'goal': 20000.0,
#   'launched': '2016-09-24 16:24:10',
#   'pledged': 4804.0,
#   'state': 'failed',
#   'backers': 13,
#   'country': 'FR',
#   'usd pledged': 3956.09317376,
#   'usd_pledged_real': 5246.947290242251},
#  {'_id': ObjectId('5fc4e26492f46015ba4655ee'),
#   'ID': 1378651384,
#   'name': 'Record Label and Charity Organisation',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2017-11-20',
#   'goal': 20000.0,
#   'launched': '2017-10-16 02:03:15',
#   'pledged': 65.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 77.20081714095681},
#  {'_id': ObjectId('5fc4e26492f46015ba465609'),
#   'ID': 945918943,
#   'name': 'Victory',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-07-08',
#   'goal': 11000.0,
#   'launched': '2016-06-23 15:59:07',
#   'pledged': 205.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 230.7825671,
#   'usd_pledged_real': 226.9355945712577},
#  {'_id': ObjectId('5fc4e26492f46015ba465636'),
#   'ID': 506704758,
#   'name': 'Les "m?andres" d\'un fleuve indien, film?s ? Chennai',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2016-06-01',
#   'goal': 3000.0,
#   'launched': '2016-05-02 22:43:39',
#   'pledged': 380.0,
#   'state': 'failed',
#   'backers': 13,
#   'country': 'FR',
#   'usd pledged': 435.0648538,
#   'usd_pledged_real': 423.8516965221853},
#  {'_id': ObjectId('5fc4e26492f46015ba46571a'),
#   'ID': 1033850816,
#   'name': 'S U Z A N N E Ceremony, Headpieces and Accessories',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-12-28',
#   'goal': 3000.0,
#   'launched': '2016-11-28 17:04:39',
#   'pledged': 855.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'FR',
#   'usd pledged': 15.8915139,
#   'usd_pledged_real': 901.2522663068685},
#  {'_id': ObjectId('5fc4e26492f46015ba465738'),
#   'ID': 481687416,
#   'name': 'Naval Battle in Archipelago (board game)',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-12-16',
#   'goal': 5000.0,
#   'launched': '2016-11-16 12:26:26',
#   'pledged': 10254.0,
#   'state': 'successful',
#   'backers': 136,
#   'country': 'FR',
#   'usd pledged': 3086.43303573,
#   'usd_pledged_real': 10704.10773004854},
#  {'_id': ObjectId('5fc4e26492f46015ba465772'),
#   'ID': 2082679032,
#   'name': 'Fart in the bottle (Suspended)',
#   'category': 'Conceptual Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2016-02-17',
#   'goal': 50.0,
#   'launched': '2016-01-18 21:02:26',
#   'pledged': 0.0,
#   'state': 'suspended',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba46595a'),
#   'ID': 1787211494,
#   'name': 'FURCY&FAIR',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-27',
#   'goal': 9000.0,
#   'launched': '2015-06-26 13:48:57',
#   'pledged': 9392.0,
#   'state': 'successful',
#   'backers': 71,
#   'country': 'FR',
#   'usd pledged': 10525.65516128,
#   'usd_pledged_real': 10300.165601044057},
#  {'_id': ObjectId('5fc4e26492f46015ba465990'),
#   'ID': 2039344600,
#   'name': 'ECOUTE SACHA',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2016-10-26',
#   'goal': 5000.0,
#   'launched': '2016-09-26 22:31:43',
#   'pledged': 171.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 186.76685816640816},
#  {'_id': ObjectId('5fc4e26492f46015ba465a47'),
#   'ID': 1271446122,
#   'name': 'The Group',
#   'category': 'Experimental',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2016-03-11',
#   'goal': 397.0,
#   'launched': '2016-02-08 10:13:46',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba465b67'),
#   'ID': 537199454,
#   'name': 'www.worldoo.info Moteur de Recherche',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-11',
#   'goal': 1000000.0,
#   'launched': '2015-06-12 01:10:53',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba465c24'),
#   'ID': 1531137241,
#   'name': 'SENS VR | A VR GAME IN A GRAPHIC MAZE',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-04-30',
#   'goal': 15000.0,
#   'launched': '2016-03-16 11:05:55',
#   'pledged': 4405.0,
#   'state': 'failed',
#   'backers': 120,
#   'country': 'FR',
#   'usd pledged': 4893.92244705,
#   'usd_pledged_real': 5033.595392631868},
#  {'_id': ObjectId('5fc4e26492f46015ba465d0e'),
#   'ID': 2054450591,
#   'name': 'Foxtrot Quarter airsoft/paintball',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-06-14',
#   'goal': 5000.0,
#   'launched': '2017-04-16 15:40:51',
#   'pledged': 25.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 26.53249000000001,
#   'usd_pledged_real': 27.917364600781692},
#  {'_id': ObjectId('5fc4e26492f46015ba465d2a'),
#   'ID': 1463240251,
#   'name': 'Video Digital Painting',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2016-06-05',
#   'goal': 50.0,
#   'launched': '2016-05-20 02:30:37',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.12957591,
#   'usd_pledged_real': 1.1304033279073973},
#  {'_id': ObjectId('5fc4e26492f46015ba465d69'),
#   'ID': 1041313518,
#   'name': 'Handmade beauty box With natural ingredients',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2016-05-29',
#   'goal': 1500.0,
#   'launched': '2016-04-29 17:48:36',
#   'pledged': 108.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'FR',
#   'usd pledged': 122.39721756,
#   'usd_pledged_real': 120.46311374841056},
#  {'_id': ObjectId('5fc4e26492f46015ba465e7c'),
#   'ID': 598062270,
#   'name': "Tonight I'll Dream About You",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-21',
#   'goal': 5900.0,
#   'launched': '2015-06-22 19:17:34',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba465fb3'),
#   'ID': 1489544702,
#   'name': 'Street Business - Pixelated & hilarious gang management game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-11-20',
#   'goal': 8000.0,
#   'launched': '2016-10-21 09:48:15',
#   'pledged': 212.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 21.9587176,
#   'usd_pledged_real': 224.55010539026173},
#  {'_id': ObjectId('5fc4e26492f46015ba4660b0'),
#   'ID': 330636006,
#   'name': 'Masaari, the african inspired fashion with a french touch.',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-03-16',
#   'goal': 15000.0,
#   'launched': '2016-02-05 17:24:48',
#   'pledged': 20.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 22.17735,
#   'usd_pledged_real': 22.558087074216104},
#  {'_id': ObjectId('5fc4e26492f46015ba4660b9'),
#   'ID': 815508717,
#   'name': 'Exorcise The Demons ï¿½ A dark fantasy cooperation game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-06-17',
#   'goal': 10000.0,
#   'launched': '2017-05-18 17:11:17',
#   'pledged': 10316.0,
#   'state': 'successful',
#   'backers': 176,
#   'country': 'FR',
#   'usd pledged': 792.35692139,
#   'usd_pledged_real': 11526.12819968492},
#  {'_id': ObjectId('5fc4e26492f46015ba46617e'),
#   'ID': 668531481,
#   'name': 'Klash',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-08-05',
#   'goal': 8000.0,
#   'launched': '2016-07-06 17:58:37',
#   'pledged': 4437.0,
#   'state': 'failed',
#   'backers': 100,
#   'country': 'FR',
#   'usd pledged': 2284.69632804,
#   'usd_pledged_real': 4949.9096365380765},
#  {'_id': ObjectId('5fc4e26492f46015ba4661c3'),
#   'ID': 766744198,
#   'name': 'eowave quadrantid swarm - experimental touch synthesizer',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-12-07',
#   'goal': 10000.0,
#   'launched': '2017-11-07 16:29:17',
#   'pledged': 34579.0,
#   'state': 'successful',
#   'backers': 82,
#   'country': 'FR',
#   'usd pledged': 8362.37658438,
#   'usd_pledged_real': 40602.836879432616},
#  {'_id': ObjectId('5fc4e26492f46015ba466237'),
#   'ID': 1102947839,
#   'name': 'Winy Nutz',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-10-19',
#   'goal': 10000.0,
#   'launched': '2017-09-20 18:53:14',
#   'pledged': 22.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 25.999503645839486},
#  {'_id': ObjectId('5fc4e26492f46015ba4662bc'),
#   'ID': 765843115,
#   'name': 'The World at Yours Fingers Tips',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-08-21',
#   'goal': 6000.0,
#   'launched': '2016-08-06 08:46:33',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.257998961320478},
#  {'_id': ObjectId('5fc4e26492f46015ba4662e4'),
#   'ID': 1096704859,
#   'name': 'Anakeen Marko : Le monde de geniusis (Geniusis World)',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2016-07-28',
#   'goal': 1500.0,
#   'launched': '2016-05-30 17:42:03',
#   'pledged': 1260.0,
#   'state': 'failed',
#   'backers': 28,
#   'country': 'FR',
#   'usd pledged': 595.77201856,
#   'usd_pledged_real': 1400.2333722287046},
#  {'_id': ObjectId('5fc4e26492f46015ba466416'),
#   'ID': 178092345,
#   'name': 'STEEVE MOREL NEW DESIGNER. Another universe of shoes.',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-03-09',
#   'goal': 15000.0,
#   'launched': '2016-02-23 17:20:31',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.11120371,
#   'usd_pledged_real': 1.1090040035044526},
#  {'_id': ObjectId('5fc4e26492f46015ba4664cf'),
#   'ID': 1046340865,
#   'name': 'Tikiwi, a "Kiwi style" Food Truck in France!',
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-12-14',
#   'goal': 10000.0,
#   'launched': '2015-10-25 19:27:21',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba4664fe'),
#   'ID': 114158706,
#   'name': 'Tiny-house alsace-Vivre autrement',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2018-01-19',
#   'goal': 40000.0,
#   'launched': '2017-11-20 06:08:32',
#   'pledged': 0.0,
#   'state': 'live',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba46653d'),
#   'ID': 630729432,
#   'name': 'Folky-Dolls... Cute LED table lamps for kids of the world!',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-20',
#   'goal': 130000.0,
#   'launched': '2015-06-09 06:13:23',
#   'pledged': 1266.0,
#   'state': 'failed',
#   'backers': 16,
#   'country': 'FR',
#   'usd pledged': 1405.16937972,
#   'usd_pledged_real': 1384.8779207140985},
#  {'_id': ObjectId('5fc4e26492f46015ba4665aa'),
#   'ID': 1796915224,
#   'name': "Tog?ther, a documentary meeting people's reality",
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'EUR',
#   'deadline': '2016-07-07',
#   'goal': 2000.0,
#   'launched': '2016-06-07 19:01:16',
#   'pledged': 2001.0,
#   'state': 'successful',
#   'backers': 22,
#   'country': 'FR',
#   'usd pledged': 2269.68535554,
#   'usd_pledged_real': 2215.1128035955453},
#  {'_id': ObjectId('5fc4e26492f46015ba4665c0'),
#   'ID': 912757617,
#   'name': 'Siesta, Nap.',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-12-31',
#   'goal': 10000.0,
#   'launched': '2015-12-01 18:45:21',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.2934756,
#   'usd_pledged_real': 5.443480343592482},
#  {'_id': ObjectId('5fc4e26492f46015ba4665fb'),
#   'ID': 843432320,
#   'name': 'Luxury Automatic Watch "Thunderbird II" Made in France',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-06-27',
#   'goal': 140000.0,
#   'launched': '2016-05-27 09:09:05',
#   'pledged': 11558.0,
#   'state': 'failed',
#   'backers': 9,
#   'country': 'FR',
#   'usd pledged': 12918.46987306,
#   'usd_pledged_real': 12869.820838019308},
#  {'_id': ObjectId('5fc4e26492f46015ba4667bc'),
#   'ID': 1515614634,
#   'name': 'Chronologia Trigalight Dive Watch',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-08-07',
#   'goal': 35500.0,
#   'launched': '2015-07-08 08:20:48',
#   'pledged': 12445.0,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'FR',
#   'usd pledged': 13734.97515005,
#   'usd_pledged_real': 13616.122714690533},
#  {'_id': ObjectId('5fc4e26492f46015ba4667f4'),
#   'ID': 629586349,
#   'name': 'HUMANIMAGES',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-07-16',
#   'goal': 20000.0,
#   'launched': '2015-06-16 23:30:42',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba466824'),
#   'ID': 903896455,
#   'name': 'Vegidair the herb garden in your kitchen',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-12-08',
#   'goal': 20000.0,
#   'launched': '2016-10-24 08:56:21',
#   'pledged': 20829.0,
#   'state': 'successful',
#   'backers': 75,
#   'country': 'FR',
#   'usd pledged': 2940.34401011,
#   'usd_pledged_real': 21993.326716364325},
#  {'_id': ObjectId('5fc4e26492f46015ba466842'),
#   'ID': 100525355,
#   'name': 'The Stolen Crystals',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-06-02',
#   'goal': 500.0,
#   'launched': '2016-05-03 18:27:47',
#   'pledged': 15.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 17.200316100000002,
#   'usd_pledged_real': 16.730988020612582},
#  {'_id': ObjectId('5fc4e26492f46015ba46687d'),
#   'ID': 1393614849,
#   'name': 'I C Q',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2016-03-24',
#   'goal': 3850.0,
#   'launched': '2016-02-08 19:45:25',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.1159282,
#   'usd_pledged_real': 1.1153992013741718},
#  {'_id': ObjectId('5fc4e26492f46015ba46688e'),
#   'ID': 2103108924,
#   'name': 'LIVING PLANET by Christophe Boelinger',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-12-15',
#   'goal': 8000.0,
#   'launched': '2017-11-21 20:02:38',
#   'pledged': 209815.0,
#   'state': 'successful',
#   'backers': 2495,
#   'country': 'FR',
#   'usd pledged': 55254.709867699996,
#   'usd_pledged_real': 247706.6927971855},
#  {'_id': ObjectId('5fc4e26492f46015ba4668be'),
#   'ID': 1636195774,
#   'name': 'Wopilo: a revolutionary pillow that will change your nights',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-07-05',
#   'goal': 20000.0,
#   'launched': '2017-05-30 09:11:49',
#   'pledged': 106463.0,
#   'state': 'successful',
#   'backers': 1013,
#   'country': 'FR',
#   'usd pledged': 24465.89012108,
#   'usd_pledged_real': 121495.65773106462},
#  {'_id': ObjectId('5fc4e26492f46015ba4668c8'),
#   'ID': 137985493,
#   'name': "Grandpa, How Do You Make a  Kachina? - A children's book",
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-12-18',
#   'goal': 7000.0,
#   'launched': '2015-11-13 18:05:08',
#   'pledged': 7000.0,
#   'state': 'successful',
#   'backers': 84,
#   'country': 'FR',
#   'usd pledged': 7534.124220000002,
#   'usd_pledged_real': 7585.198027848513},
#  {'_id': ObjectId('5fc4e26492f46015ba4668f0'),
#   'ID': 55610700,
#   'name': 'May TheFrenchKiss be the universal way of communication !',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-07-23',
#   'goal': 10000.0,
#   'launched': '2016-06-21 10:51:04',
#   'pledged': 11712.17,
#   'state': 'successful',
#   'backers': 93,
#   'country': 'FR',
#   'usd pledged': 11753.4886181128,
#   'usd_pledged_real': 13015.69150413958},
#  {'_id': ObjectId('5fc4e26492f46015ba466a17'),
#   'ID': 2124363311,
#   'name': 'PrEttiO: A fashion-first 5 in 1 bracelet for smartphones',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-03-27',
#   'goal': 75000.0,
#   'launched': '2017-01-31 16:19:56',
#   'pledged': 1770.0,
#   'state': 'failed',
#   'backers': 16,
#   'country': 'FR',
#   'usd pledged': 398.06354476,
#   'usd_pledged_real': 1892.2993040187305},
#  {'_id': ObjectId('5fc4e26492f46015ba466a35'),
#   'ID': 528975230,
#   'name': 'Moea Swimwear, exclusive designs and eco-line',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2017-11-16',
#   'goal': 5000.0,
#   'launched': '2017-10-17 09:32:54',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba466a88'),
#   'ID': 1541410513,
#   'name': 'JOCLY:(R)EVOLUTION for Chess, Variants and Board Games.',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-05-31',
#   'goal': 420000.0,
#   'launched': '2016-04-01 02:35:08',
#   'pledged': 151.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 170.50895236,
#   'usd_pledged_real': 168.42527940749994},
#  {'_id': ObjectId('5fc4e26492f46015ba466b3f'),
#   'ID': 223390511,
#   'name': 'Move!',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-08-31',
#   'goal': 150000.0,
#   'launched': '2016-08-01 16:10:25',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba466b8f'),
#   'ID': 100609913,
#   'name': 'Martin Persil, la cantine vegan ? roulettes !',
#   'category': 'Vegan',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2016-02-15',
#   'goal': 7500.0,
#   'launched': '2016-01-11 18:30:49',
#   'pledged': 9172.0,
#   'state': 'successful',
#   'backers': 193,
#   'country': 'FR',
#   'usd pledged': 10019.67449732,
#   'usd_pledged_real': 10177.202268011497},
#  {'_id': ObjectId('5fc4e26492f46015ba466be1'),
#   'ID': 452512093,
#   'name': 'The Idol of Cthulhu, a scenario & props for Call of Cthulhu',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-12-27',
#   'goal': 5000.0,
#   'launched': '2017-12-06 20:21:09',
#   'pledged': 18614.0,
#   'state': 'successful',
#   'backers': 220,
#   'country': 'FR',
#   'usd pledged': 5592.98454592,
#   'usd_pledged_real': 22323.762922453287},
#  {'_id': ObjectId('5fc4e26492f46015ba466cc1'),
#   'ID': 1603537050,
#   'name': 'Rescue ARTISANAL spicy original CONDIMENT SAUCES for experts',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2016-07-05',
#   'goal': 155500.0,
#   'launched': '2016-05-11 15:34:34',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba466d52'),
#   'ID': 494287474,
#   'name': 'Berry Project',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2017-05-15',
#   'goal': 2500.0,
#   'launched': '2017-04-15 21:12:01',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 26.534236,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba466d74'),
#   'ID': 601724985,
#   'name': 'Shampoing MARLIVEIRA',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-10-25',
#   'goal': 15000.0,
#   'launched': '2015-09-25 20:41:48',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba466e4d'),
#   'ID': 293502696,
#   'name': 'Reines Des Temps Modernes',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2016-03-08',
#   'goal': 15000.0,
#   'launched': '2016-01-28 22:34:18',
#   'pledged': 4012.0,
#   'state': 'failed',
#   'backers': 115,
#   'country': 'FR',
#   'usd pledged': 4359.2869446,
#   'usd_pledged_real': 4449.3240620598635},
#  {'_id': ObjectId('5fc4e26492f46015ba466eae'),
#   'ID': 338426049,
#   'name': 'Asterion- By director of FMA Brotherhood (Canceled)',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-28',
#   'goal': 135000.0,
#   'launched': '2015-06-13 11:55:03',
#   'pledged': 33785.0,
#   'state': 'canceled',
#   'backers': 155,
#   'country': 'FR',
#   'usd pledged': 38021.59406595,
#   'usd_pledged_real': 37051.8627375717},
#  {'_id': ObjectId('5fc4e26492f46015ba466eba'),
#   'ID': 1640048861,
#   'name': 'ARBITRELEC',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-11-30',
#   'goal': 25000.0,
#   'launched': '2015-10-31 17:01:23',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba466f14'),
#   'ID': 1498260950,
#   'name': 'children all around the world',
#   'category': 'People',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2016-06-23',
#   'goal': 3000.0,
#   'launched': '2016-05-23 22:22:03',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.12224125,
#   'usd_pledged_real': 1.1065986477364524},
#  {'_id': ObjectId('5fc4e26492f46015ba466f23'),
#   'ID': 1814018517,
#   'name': 'Pouvoir vendre mes illustrations / To sell my illustrations',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2016-09-24',
#   'goal': 400.0,
#   'launched': '2016-08-25 18:51:14',
#   'pledged': 130.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 50.84458515,
#   'usd_pledged_real': 145.0925243867051},
#  {'_id': ObjectId('5fc4e26492f46015ba466f6c'),
#   'ID': 498704725,
#   'name': 'Andiaho illustrations',
#   'category': 'Interactive Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-11-19',
#   'goal': 27000.0,
#   'launched': '2017-10-02 15:43:30',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba466fd1'),
#   'ID': 1072534785,
#   'name': 'Book - Retracing our steps - Fukushima exclusion zone',
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2016-07-31',
#   'goal': 25000.0,
#   'launched': '2016-06-16 02:37:40',
#   'pledged': 26826.0,
#   'state': 'successful',
#   'backers': 175,
#   'country': 'FR',
#   'usd pledged': 13511.30065044,
#   'usd_pledged_real': 29927.03987148308},
#  {'_id': ObjectId('5fc4e26492f46015ba466ff9'),
#   'ID': 887517629,
#   'name': 'Photo Gallery',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-03-13',
#   'goal': 51720.0,
#   'launched': '2017-01-30 22:02:14',
#   'pledged': 15.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 16.105480158048447},
#  {'_id': ObjectId('5fc4e26492f46015ba4670da'),
#   'ID': 378181109,
#   'name': 'tiny & Tall: Gleipnir',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-08',
#   'goal': 8000.0,
#   'launched': '2015-09-08 09:03:03',
#   'pledged': 6817.0,
#   'state': 'failed',
#   'backers': 268,
#   'country': 'FR',
#   'usd pledged': 7603.20147418,
#   'usd_pledged_real': 7745.446695374547},
#  {'_id': ObjectId('5fc4e26492f46015ba467111'),
#   'ID': 1456620554,
#   'name': 'Shirel : Very special new songs need you',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2017-03-19',
#   'goal': 26000.0,
#   'launched': '2017-01-18 14:50:26',
#   'pledged': 1184.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 702.2501772,
#   'usd_pledged_real': 1279.308481901675},
#  {'_id': ObjectId('5fc4e26492f46015ba4671c6'),
#   'ID': 1730882800,
#   'name': '100 MECA',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-08-06',
#   'goal': 8000.0,
#   'launched': '2015-07-12 01:47:15',
#   'pledged': 320.0,
#   'state': 'failed',
#   'backers': 13,
#   'country': 'FR',
#   'usd pledged': 354.7722976,
#   'usd_pledged_real': 350.11323975098196},
#  {'_id': ObjectId('5fc4e26492f46015ba4671f4'),
#   'ID': 659474508,
#   'name': 'Love Lighters',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-04-03',
#   'goal': 18000.0,
#   'launched': '2016-02-03 20:27:23',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba46725b'),
#   'ID': 1436923239,
#   'name': 'T(h)anks Lyon',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-01-11',
#   'goal': 5000.0,
#   'launched': '2016-11-12 23:56:51',
#   'pledged': 6044.0,
#   'state': 'successful',
#   'backers': 27,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 6443.496801705757},
#  {'_id': ObjectId('5fc4e26492f46015ba467272'),
#   'ID': 901276704,
#   'name': 'BIBIGO,biberon Nomade, Pro-actif et v?g?tal 330 ML',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-01-24',
#   'goal': 7000.0,
#   'launched': '2016-12-24 14:26:14',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba4672a2'),
#   'ID': 2047022279,
#   'name': 'DROBOT X - Drones & Robots Park',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-03-15',
#   'goal': 125000.0,
#   'launched': '2017-02-10 11:18:53',
#   'pledged': 7935.0,
#   'state': 'failed',
#   'backers': 25,
#   'country': 'FR',
#   'usd pledged': 6145.5457774999995,
#   'usd_pledged_real': 8519.799003607628},
#  {'_id': ObjectId('5fc4e26492f46015ba467329'),
#   'ID': 2120056774,
#   'name': 'Le livre des Hrabst',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2016-03-25',
#   'goal': 2000.0,
#   'launched': '2016-01-25 17:58:05',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.39875765,
#   'usd_pledged_real': 5.715984178155796},
#  {'_id': ObjectId('5fc4e26492f46015ba4673aa'),
#   'ID': 1943924777,
#   'name': 'PAMPA FOLKS enregistre son 1er Album "Indie Pop Western"',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2017-01-15',
#   'goal': 4000.0,
#   'launched': '2016-12-16 02:35:19',
#   'pledged': 6853.0,
#   'state': 'successful',
#   'backers': 109,
#   'country': 'FR',
#   'usd pledged': 1835.8772463,
#   'usd_pledged_real': 7286.084885600068},
#  {'_id': ObjectId('5fc4e26492f46015ba467584'),
#   'ID': 1330309415,
#   'name': 'Today is a good day',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-11',
#   'goal': 25000.0,
#   'launched': '2015-05-27 11:06:11',
#   'pledged': 285.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 312.08081115,
#   'usd_pledged_real': 310.3358160198615},
#  {'_id': ObjectId('5fc4e26492f46015ba4677cd'),
#   'ID': 256752754,
#   'name': 'Ostrich-Dalmatians Pack',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2017-12-10',
#   'goal': 1500.0,
#   'launched': '2017-11-10 11:36:58',
#   'pledged': 110.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 129.86553014651193},
#  {'_id': ObjectId('5fc4e26492f46015ba467820'),
#   'ID': 355911884,
#   'name': 'Andr?s de Jerez "Ara?ando el alma", le disque d\'une vie',
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2017-05-31',
#   'goal': 2889.0,
#   'launched': '2017-05-01 14:37:47',
#   'pledged': 4002.0,
#   'state': 'successful',
#   'backers': 69,
#   'country': 'FR',
#   'usd pledged': 1031.85456185,
#   'usd_pledged_real': 4489.063376332025},
#  {'_id': ObjectId('5fc4e26492f46015ba46782e'),
#   'ID': 171285045,
#   'name': 'CrewMe New Version',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-06-21',
#   'goal': 20000.0,
#   'launched': '2016-05-17 16:24:09',
#   'pledged': 485.0,
#   'state': 'failed',
#   'backers': 26,
#   'country': 'FR',
#   'usd pledged': 548.47005365,
#   'usd_pledged_real': 536.7003441521795},
#  {'_id': ObjectId('5fc4e26492f46015ba467993'),
#   'ID': 327985277,
#   'name': 'TOP SCHOOL',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-27',
#   'goal': 20000.0,
#   'launched': '2015-05-28 21:40:45',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26492f46015ba4679f1'),
#   'ID': 1426441163,
#   'name': 'Abstract Atlas of the World ï¿½ Atlas Abstrait du Monde',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2017-05-21',
#   'goal': 13000.0,
#   'launched': '2017-04-21 12:12:29',
#   'pledged': 17783.0,
#   'state': 'successful',
#   'backers': 144,
#   'country': 'FR',
#   'usd pledged': 3604.14831896,
#   'usd_pledged_real': 19909.760630556},
#  {'_id': ObjectId('5fc4e26492f46015ba4679fe'),
#   'ID': 1547060564,
#   'name': "Manman doudou t?moignage d'une m?re Album",
#   'category': 'Faith',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2017-04-07',
#   'goal': 3500.0,
#   'launched': '2017-03-14 19:45:38',
#   'pledged': 1195.0,
#   'state': 'failed',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 887.8572167000003,
# ...
#   'state': 'failed',
#   'backers': '1',
#   'country': 'FR',
#   'usd pledged': '0.0',
#   'usd_pledged_real': 1.1092992556601995},
#  {'_id': ObjectId('5fc4e26892f46015ba482af8'),
#   'ID': 55876971,
#   'name': 'Plugin Mondial Relay pour WPshop e-commerce sur Wordpress',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-03-29',
#   'goal': '550.0',
#   'launched': '2016-03-09 18:12:12',
#   'pledged': '30.0',
#   'state': 'failed',
#   'backers': '2',
#   'country': 'FR',
#   'usd pledged': '33.062696700000004',
#   'usd_pledged_real': 34.29590506893477},
#  {'_id': ObjectId('5fc4e26892f46015ba482b44'),
#   'ID': 387759019,
#   'name': 'Art of Anndr : A Fantasy Artbook',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2016-01-17',
#   'goal': '1800.0',
#   'launched': '2015-12-08 20:02:36',
#   'pledged': '7195.0',
#   'state': 'successful',
#   'backers': '138',
#   'country': 'FR',
#   'usd pledged': '7813.8744714',
#   'usd_pledged_real': 7776.360728027323},
#  {'_id': ObjectId('5fc4e26892f46015ba482b6f'),
#   'ID': 1812692728,
#   'name': '1000 Skateboard - 1000MORTEL Dude mod?le du Alex R?tine',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2017-10-30',
#   'goal': '1200.0',
#   'launched': '2017-09-30 09:44:15',
#   'pledged': '1203.0',
#   'state': 'successful',
#   'backers': '24',
#   'country': 'FR',
#   'usd pledged': '271.04135180000003',
#   'usd_pledged_real': 1402.34306696975},
#  {'_id': ObjectId('5fc4e26892f46015ba482c5a'),
#   'ID': 1227483133,
#   'name': 'New Innovative Speaker System for Digital Cinema Worldwide',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-04-30',
#   'goal': '45000.0',
#   'launched': '2017-03-01 14:01:10',
#   'pledged': '2.0',
#   'state': 'failed',
#   'backers': '2',
#   'country': 'FR',
#   'usd pledged': '0.0',
#   'usd_pledged_real': 2.1921892297743137},
#  {'_id': ObjectId('5fc4e26892f46015ba482c60'),
#   'ID': 246508367,
#   'name': '[ A L P H A ] PROJECT - Major Evolution in Helmet History !',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2016-04-29',
#   'goal': '200000.0',
#   'launched': '2016-03-15 20:01:42',
#   'pledged': '15431.0',
#   'state': 'failed',
#   'backers': '97',
#   'country': 'FR',
#   'usd pledged': '17214.60525135',
#   'usd_pledged_real': 17596.013501185917},
#  {'_id': ObjectId('5fc4e26892f46015ba482d45'),
#   'ID': 963828033,
#   'name': 'Un Amour politiquement incorrect',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-07-23',
#   'goal': '2000.0',
#   'launched': '2015-06-08 12:07:38',
#   'pledged': '105.0',
#   'state': 'failed',
#   'backers': '4',
#   'country': 'FR',
#   'usd pledged': '116.69207970000001',
#   'usd_pledged_real': 114.85954318718824},
#  {'_id': ObjectId('5fc4e26892f46015ba482e0c'),
#   'ID': 1060219091,
#   'name': 'Breakleague : ligue de breakdance',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': '2016-07-25',
#   'goal': '10000.0',
#   'launched': '2016-05-26 17:22:44',
#   'pledged': '10585.0',
#   'state': 'successful',
#   'backers': '112',
#   'country': 'FR',
#   'usd pledged': '9282.50097816',
#   'usd_pledged_real': 11763.071623048283},
#  {'_id': ObjectId('5fc4e26892f46015ba482e87'),
#   'ID': 916249508,
#   'name': 'Jarduino',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-11-30',
#   'goal': '2500.0',
#   'launched': '2016-11-08 17:56:03',
#   'pledged': '1048.0',
#   'state': 'failed',
#   'backers': '20',
#   'country': 'FR',
#   'usd pledged': '478.64384352',
#   'usd_pledged_real': 1115.2851532984985},
#  {'_id': ObjectId('5fc4e26892f46015ba482eda'),
#   'ID': 2029345617,
#   'name': 'Mozzaika Borders Part1: Brazil',
#   'category': 'Music Videos',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2017-02-08',
#   'goal': '8000.0',
#   'launched': '2017-01-04 19:37:20',
#   'pledged': '8110.0',
#   'state': 'successful',
#   'backers': '87',
#   'country': 'FR',
#   'usd pledged': '597.9016824',
#   'usd_pledged_real': 8620.139877978785},
#  {'_id': ObjectId('5fc4e26892f46015ba482f08'),
#   'ID': 399743090,
#   'name': 'Ekimana - Sustainable table ware & deco collection',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2017-10-08',
#   'goal': '13000.0',
#   'launched': '2017-09-11 17:45:27',
#   'pledged': '2047.0',
#   'state': 'canceled',
#   'backers': '18',
#   'country': 'FR',
#   'usd pledged': '46.93705614',
#   'usd_pledged_real': 2417.5071450504292},
#  {'_id': ObjectId('5fc4e26892f46015ba482f9a'),
#   'ID': 1911721595,
#   'name': 'Leather Moccasins / Natural footwear for Earth lovers',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-05-02',
#   'goal': '1520.0',
#   'launched': '2016-04-02 10:32:04',
#   'pledged': '1530.0',
#   'state': 'successful',
#   'backers': '16',
#   'country': 'FR',
#   'usd pledged': '1739.8226088',
#   'usd_pledged_real': 1748.3316573727031},
#  {'_id': ObjectId('5fc4e26892f46015ba482fb6'),
#   'ID': 1880302664,
#   'name': 'Mets Ton Slip ! Le jeu de cartes culott?...',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-07-04',
#   'goal': '3000.0',
#   'launched': '2015-05-29 11:59:47',
#   'pledged': '3963.0',
#   'state': 'successful',
#   'backers': '131',
#   'country': 'FR',
#   'usd pledged': '4322.08299144',
#   'usd_pledged_real': 4432.637995637828},
#  {'_id': ObjectId('5fc4e26892f46015ba48301f'),
#   'ID': 979235909,
#   'name': "Esca'Pad in Madagascar",
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2017-11-12',
#   'goal': '10000.0',
#   'launched': '2017-10-04 11:21:05',
#   'pledged': '11538.0',
#   'state': 'successful',
#   'backers': '210',
#   'country': 'FR',
#   'usd pledged': '4576.600103600001',
#   'usd_pledged_real': 13609.02078271331},
#  {'_id': ObjectId('5fc4e26892f46015ba483035'),
#   'ID': 669758354,
#   'name': 'PANAMERS Paris - Blackout Edition',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-10-12',
#   'goal': '10000.0',
#   'launched': '2016-09-12 19:45:53',
#   'pledged': '12920.0',
#   'state': 'successful',
#   'backers': '83',
#   'country': 'FR',
#   'usd pledged': '7199.4159862000015',
#   'usd_pledged_real': 14214.51596932657},
#  {'_id': ObjectId('5fc4e26892f46015ba4830b2'),
#   'ID': 188570011,
#   'name': 'Collection : Le tableau num?rique',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2018-01-23',
#   'goal': '16000.0',
#   'launched': '2017-11-24 00:00:23',
#   'pledged': '370.0',
#   'state': 'live',
#   'backers': '4',
#   'country': 'FR',
#   'usd pledged': '0.0',
#   'usd_pledged_real': 449.0672751325962},
#  {'_id': ObjectId('5fc4e26892f46015ba4830b7'),
#   'ID': 634861947,
#   'name': 'Thea Rainbow',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-06-28',
#   'goal': '25000.0',
#   'launched': '2015-05-29 16:18:20',
#   'pledged': '38326.0',
#   'state': 'successful',
#   'backers': '174',
#   'country': 'FR',
#   'usd pledged': '41798.67593488',
#   'usd_pledged_real': 42526.32513342876},
#  {'_id': ObjectId('5fc4e26892f46015ba483130'),
#   'ID': 1680186374,
#   'name': 'Elegant Universe: A World Dance Spectacular with Live Music',
#   'category': 'Performances',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': '2016-03-08',
#   'goal': '6000.0',
#   'launched': '2016-02-01 11:02:06',
#   'pledged': '6825.5',
#   'state': 'successful',
#   'backers': '150',
#   'country': 'FR',
#   'usd pledged': '7392.529163305',
#   'usd_pledged_real': 7569.506825919641},
#  {'_id': ObjectId('5fc4e26892f46015ba48316a'),
#   'ID': 363141153,
#   'name': 'Palais de la Culture et des Arts',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2017-06-30',
#   'goal': '25000000.0',
#   'launched': '2017-06-16 09:19:51',
#   'pledged': '130.0',
#   'state': 'failed',
#   'backers': '2',
#   'country': 'FR',
#   'usd pledged': '89.7800056',
#   'usd_pledged_real': 148.3561002887238},
#  {'_id': ObjectId('5fc4e26892f46015ba483176'),
#   'ID': 285528944,
#   'name': 'Extraction Lyrique: Award winning Abstract Photography book',
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-11-10',
#   'goal': '8000.0',
#   'launched': '2015-09-26 03:05:17',
#   'pledged': '1013.0',
#   'state': 'failed',
#   'backers': '12',
#   'country': 'FR',
#   'usd pledged': '1132.7421715',
#   'usd_pledged_real': 1090.3963316182644},
#  {'_id': ObjectId('5fc4e26892f46015ba483182'),
#   'ID': 1484561446,
#   'name': 'WikUps Plate-forme de Micro-Blogging',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': '50000.0',
#   'launched': '2015-05-27 07:29:17',
#   'pledged': '0.0',
#   'state': 'failed',
#   'backers': '0',
#   'country': 'FR',
#   'usd pledged': '0.0',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26892f46015ba4831bb'),
#   'ID': 1744433292,
#   'name': 'E-One - A New Elegant Watch',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-12-15',
#   'goal': '25000.0',
#   'launched': '2016-10-31 12:54:36',
#   'pledged': '2990.0',
#   'state': 'failed',
#   'backers': '31',
#   'country': 'FR',
#   'usd pledged': '1841.65704672',
#   'usd_pledged_real': 3121.24849939976},
#  {'_id': ObjectId('5fc4e26892f46015ba4831c5'),
#   'ID': 1854878965,
#   'name': 'The Keys : partagez et contr?lez les acc?s',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-03-22',
#   'goal': '50000.0',
#   'launched': '2017-02-15 12:39:44',
#   'pledged': '86852.0',
#   'state': 'successful',
#   'backers': '357',
#   'country': 'FR',
#   'usd pledged': '2659.06367328',
#   'usd_pledged_real': 93843.3279308482},
#  {'_id': ObjectId('5fc4e26892f46015ba48325f'),
#   'ID': 2085182716,
#   'name': 'Rachetons T?TU',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'EUR',
#   'deadline': '2015-09-18',
#   'goal': '75000.0',
#   'launched': '2015-09-11 11:24:24',
#   'pledged': '5807.0',
#   'state': 'failed',
#   'backers': '58',
#   'country': 'FR',
#   'usd pledged': '6509.48399751',
#   'usd_pledged_real': 6631.0392472565745},
#  {'_id': ObjectId('5fc4e26892f46015ba4832ac'),
#   'ID': 1496835703,
#   'name': 'FITCAZE | The iPhone case that does MORE.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2017-08-01',
#   'goal': '35000.0',
#   'launched': '2017-07-06 14:12:20',
#   'pledged': '24854.0',
#   'state': 'failed',
#   'backers': '360',
#   'country': 'FR',
#   'usd pledged': '6110.955852',
#   'usd_pledged_real': 29496.79563256587},
#  {'_id': ObjectId('5fc4e26892f46015ba4832bd'),
#   'ID': 1400357949,
#   'name': 'Boat made of Plastic Bottles',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2017-07-12',
#   'goal': '500.0',
#   'launched': '2017-06-12 17:57:02',
#   'pledged': '260.0',
#   'state': 'failed',
#   'backers': '13',
#   'country': 'FR',
#   'usd pledged': '78.3699063',
#   'usd_pledged_real': 296.7901009086343},
#  {'_id': ObjectId('5fc4e26892f46015ba483385'),
#   'ID': 60275600,
#   'name': 'Pr?server les abeilles en alsace',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2017-06-02',
#   'goal': '2600.0',
#   'launched': '2017-04-18 22:57:55',
#   'pledged': '66.0',
#   'state': 'failed',
#   'backers': '3',
#   'country': 'FR',
#   'usd pledged': '29.73027204',
#   'usd_pledged_real': 74.03252944475605},
#  {'_id': ObjectId('5fc4e26892f46015ba48345e'),
#   'ID': 611537687,
#   'name': 'RBalloon faire des noeuds de ballon facilement (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-11-07',
#   'goal': '40000.0',
#   'launched': '2015-09-28 16:40:02',
#   'pledged': '57.0',
#   'state': 'canceled',
#   'backers': '1',
#   'country': 'FR',
#   'usd pledged': '63.81949596',
#   'usd_pledged_real': 61.35497621149168},
#  {'_id': ObjectId('5fc4e26892f46015ba4834c0'),
#   'ID': 421917098,
#   'name': 'BEING BLIND - The book about a different reality.',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2016-12-18',
#   'goal': '19000.0',
#   'launched': '2016-11-18 11:52:45',
#   'pledged': '3832.0',
#   'state': 'failed',
#   'backers': '46',
#   'country': 'FR',
#   'usd pledged': '663.3144338',
#   'usd_pledged_real': 4002.9248929280266},
#  {'_id': ObjectId('5fc4e26892f46015ba48359e'),
#   'ID': 819833216,
#   'name': 'Pop Art in Grenoble',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-09-02',
#   'goal': '75.0',
#   'launched': '2015-08-31 18:56:04',
#   'pledged': '100.0',
#   'state': 'successful',
#   'backers': '1',
#   'country': 'FR',
#   'usd pledged': '111.819175',
#   'usd_pledged_real': 111.37965984651882},
#  {'_id': ObjectId('5fc4e26892f46015ba4835c6'),
#   'ID': 974692673,
#   'name': 'Hazang: Luxury Bamboo Speakers, Handcrafted in Vietnam.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2016-07-14',
#   'goal': '12500.0',
#   'launched': '2016-06-14 19:59:32',
#   'pledged': '12618.0',
#   'state': 'successful',
#   'backers': '88',
#   'country': 'FR',
#   'usd pledged': '10419.60738672',
#   'usd_pledged_real': 14041.374091672878},
#  {'_id': ObjectId('5fc4e26892f46015ba4835d1'),
#   'ID': 599685767,
#   'name': 'H?ros & Sorcellerie',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2017-07-24',
#   'goal': '3500.0',
#   'launched': '2017-05-25 14:49:20',
#   'pledged': '5.0',
#   'state': 'canceled',
#   'backers': '1',
#   'country': 'FR',
#   'usd pledged': '5.5903524',
#   'usd_pledged_real': 5.86448351493684},
#  {'_id': ObjectId('5fc4e26892f46015ba4835fc'),
#   'ID': 239942926,
#   'name': 'Un coup de pouce pour mon ?quipement vid?o!',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2016-10-31',
#   'goal': '2000.0',
#   'launched': '2016-10-14 22:43:57',
#   'pledged': '2038.0',
#   'state': 'successful',
#   'backers': '21',
#   'country': 'FR',
#   'usd pledged': '176.47383200000004',
#   'usd_pledged_real': 2260.7518830354866},
#  {'_id': ObjectId('5fc4e26892f46015ba483656'),
#   'ID': 854550922,
#   'name': 'SeenApps Watch Faces on Samsung Gear S2',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-01-19',
#   'goal': '600.0',
#   'launched': '2016-01-04 19:23:32',
#   'pledged': '18.0',
#   'state': 'failed',
#   'backers': '4',
#   'country': 'FR',
#   'usd pledged': '19.54690272',
#   'usd_pledged_real': 19.45441182828239},
#  {'_id': ObjectId('5fc4e26892f46015ba4836d8'),
#   'ID': 959126311,
#   'name': 'SudoKount, number placement puzzle game inspired by Sudoku',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-11-24',
#   'goal': '10000.0',
#   'launched': '2016-10-25 20:00:54',
#   'pledged': '1279.0',
#   'state': 'failed',
#   'backers': '49',
#   'country': 'FR',
#   'usd pledged': '435.70380716',
#   'usd_pledged_real': 1354.7150226138906},
#  {'_id': ObjectId('5fc4e26892f46015ba48376b'),
#   'ID': 968043355,
#   'name': "Salle d'arcade Doga'Dha",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2016-11-30',
#   'goal': '100000.0',
#   'launched': '2016-10-31 09:49:05',
#   'pledged': '0.0',
#   'state': 'failed',
#   'backers': '0',
#   'country': 'FR',
#   'usd pledged': '0.0',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('5fc4e26892f46015ba4837c0'),
#   'ID': 425630601,
#   'name': 'PlayStation Anthology',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2017-05-05',
#   'goal': '40000.0',
#   'launched': '2017-04-05 18:08:30',
#   'pledged': '44856.0',
#   'state': 'successful',
#   'backers': '635',
#   'country': 'FR',
#   'usd pledged': '5270.2608842',
#   'usd_pledged_real': 49166.42004537832},
#  ...]

# %% [markdown]
# ## Question 5
#
# Récupérer les projets américains ayant demandé plus de 200 000 dollars.

# %%
cur = collection.find({"pledged":{"$gt": 200000}}, {"country":"US"})
list(cur)
# Out:
# [{'_id': ObjectId('5fc4e26492f46015ba4643ed'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46447d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4644d8'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46452b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464620'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46464a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464659'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46470e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464729'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464741'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4647b7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46480c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4648a0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4648f9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46497e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464a09'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464c46'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464c81'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464d66'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464e0e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba464f25'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46531e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46543c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4654ac'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465559'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465592'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4655c0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4655fc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46569b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4656b3'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46583c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465850'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465940'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465956'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465a60'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465a6d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465cd9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465e96'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba465f1f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466005'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4660a0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466208'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4663d8'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466403'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46646d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466477'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466568'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4665ef'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466670'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4666a0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4666ce'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466762'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4667a6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46688e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4669b4'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4669fd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466a36'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466a82'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466ae1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466b87'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466bb7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466c0d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466c50'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466d61'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba466e38'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467003'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46712e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4671aa'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46728e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4672f4'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467308'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4674a5'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4674b9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4674db'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467501'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467517'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4675f9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4676be'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4676e0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4677bc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467a3a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467a4e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467bce'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467c3f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467c7a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467d4e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467e45'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467e7f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467f1c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba467f52'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46810e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46822c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468238'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46824f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468281'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468290'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46830e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46836d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468676'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46878d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468896'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468901'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468919'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468931'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468ac7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468bd3'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468cb1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba468f37'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469029'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46904d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4690e6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46913f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469173'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4691fd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46929d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4693bb'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46957f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4695e3'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4696da'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46973e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba4698b3'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46998d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469995'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469a01'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469a4f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469a6d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469a71'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469bae'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469c06'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469c20'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469c62'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469d12'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469d9d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469db6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469dd7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469e04'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba469eff'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a074'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a17c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a1af'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a215'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a2d6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a3b7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a40c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a451'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a4da'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a4ed'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a629'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a733'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a839'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a8f8'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46a90c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46aa05'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46ac7c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26492f46015ba46ad2a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46afac'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b047'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b04c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b108'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b1ea'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b225'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b25b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b2c0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b40c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b479'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b4f9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b546'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b5ff'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46b97d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46ba1b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46bac4'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46baec'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46bb43'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46bba6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46bbc4'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46bc0a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46bc8d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46bc94'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46be16'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46beff'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46bf1c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c08e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c0da'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c124'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c19a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c1d0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c1de'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c336'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c409'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c594'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c5f0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c629'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c6b9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c6c2'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c738'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c744'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c74b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c78e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c81e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c87d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c888'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c923'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c9b2'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46c9fe'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46ca64'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46cabd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46cc17'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46cc66'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46cc8f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46cd45'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46ce04'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46ce9c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46cfa8'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d01b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d060'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d0b7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d35d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d37b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d3b6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d494'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d4d6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d5a2'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d68e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d6b3'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d6bc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26592f46015ba46d713'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46d804'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46d811'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46d83d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46d889'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46d8f9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46d959'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46d9b4'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46da24'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46da25'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46dab5'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46dbbf'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46dbfc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46dc58'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46dcb4'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46dd1d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46dd81'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46de2a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46dfd9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e0fd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e1e0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e390'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e412'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e622'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e633'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e73b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e7cf'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e8bd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e96b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e9e3'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46e9e6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46ea75'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46ea7b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46ea99'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46eb17'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46eb8c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46ebe2'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46ec3f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46ec6e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46ed91'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46eee4'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46ef3e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46f001'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46f062'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46f0b2'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46f15a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46f209'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46f253'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46f304'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46f450'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26692f46015ba46f4ac'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f5af'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f6b5'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f781'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f79e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f7bc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f844'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f86e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f925'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f9ab'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f9ae'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46f9c9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46fb67'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46fb77'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46fbc9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46fdf7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46fe53'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba46fffd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4701b9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4701ca'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4701e1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470222'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47023d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47027c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4702d6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4704a9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4704e1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4705ca'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4705f0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4706ba'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470742'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4708d1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470b19'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470b62'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470c5e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470cd6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470ce7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470ceb'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470e07'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470e1a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470eda'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470f2d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba470f69'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471151'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47118b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4711b5'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47136d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471391'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4714b3'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4714b9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4715b9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47162a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4716da'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471746'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47177c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4717c0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471810'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47181f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4719ed'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471a74'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471ac9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471b4c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471b78'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471c0a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471c8c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471e28'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471f44'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471f60'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba471fb1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47202f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4720b6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47211a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472258'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472295'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4722ad'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472301'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472304'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472438'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472524'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472564'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4725ba'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47262b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472830'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47284c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47297b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4729ad'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472a3a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472a57'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472a9d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472ae2'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472bb1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472d07'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472e46'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472ec7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba472f3e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473050'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47309f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4730ac'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4730b0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4730dc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473307'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473347'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473465'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4734d1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4734fe'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473615'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473653'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473692'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4736bc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4737a5'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba4737bf'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47385d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473908'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473925'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473a74'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473b57'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473bbd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473c9c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473d43'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473e16'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473ee0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473fd3'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba473fe5'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47408d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba47411a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba474159'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26792f46015ba474288'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484415'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484450'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484476'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484656'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4846aa'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4846c3'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484743'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484761'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4847aa'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4847e8'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4848bc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4849ea'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484a1d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484a81'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484b33'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484c00'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484c09'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484c91'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484cda'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484f09'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba484f8e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48502e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485138'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4851ab'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48524a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4853e1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4853e5'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485440'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485519'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485554'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48563e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485662'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485788'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48579c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485882'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485952'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485a89'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485cc4'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485d86'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485d8a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485e80'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485f30'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485f3b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba485fcd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486001'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486032'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48607c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48613d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48616e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486177'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4861a2'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486342'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486345'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4864d1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48655d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486641'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48667c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486683'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4867ce'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4867f8'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48682e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486922'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4869aa'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4869bf'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486ac6'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486aef'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486b41'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486b42'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486bb9'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486c84'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486cdd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486d85'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486dd7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486dfc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486e06'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486e18'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486e45'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486e71'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486efc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486f0f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486f3c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486f76'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486f9f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba486fab'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487085'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4870ba'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487159'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48716f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487205'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48725e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487394'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48743b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4875aa'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48766e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4876ae'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4877ac'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48784d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48785b'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487907'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487931'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4879c0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487a01'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487ad1'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487d14'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487d73'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487e6a'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487fa0'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba487ffd'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba488069'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4880c7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48816f'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4881fe'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48822d'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4882dc'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48835c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba488560'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba488572'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4886d7'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba488723'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba488750'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba488782'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48882c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba48887c'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba4889cb'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba488c96'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba488d0e'), 'country': 'US'},
#  {'_id': ObjectId('5fc4e26992f46015ba488d59'), 'country': 'US'}]

# %% [markdown]
# ## Question 6
#
# Compter le nombre de projet ayant "Sport" dans leur nom

# %%
collection.find({'name' : {'$regex':".*Sport.*"}}).count(True)
# Out:
# <ipython-input-50-40c84309e8a0>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   collection.find({'name' : {'$regex':".*Sport.*"}}).count(True)
# 323
